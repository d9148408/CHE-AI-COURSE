# %% [markdown]
# ## 0. 環境設定
# - 本教學課程使用Google Colab環境, 並使用TensorFlow/Keras模組建立RNN模型.
# - 學生也可以使用自己的電腦, 但需配備NVIDIA GPU, 建議規格為RTX 3060或更高版本.
# - 學生電腦環境安裝請參閱Part_0/Unit00_Local_Environment_Setup.ipynb.

# %%
from pathlib import Path
import tensorflow as tf
import os

# ========================================
# 路徑設定 (兼容 Colab 與 Local)
# ========================================
UNIT_OUTPUT_DIR = 'P4_Unit17_Results'
SOURCE_DATA_DIR = ''

try:
  from google.colab import drive
  IN_COLAB = True
  print("✓ 偵測到 Colab 環境，準備掛載 Google Drive...")
  drive.mount('/content/drive', force_remount=True)
except ImportError:
  IN_COLAB = False
  print("✓ 偵測到 Local 環境")

try:
  shortcut_path = '/content/CHE-AI-COURSE'
  os.remove(shortcut_path)
except FileNotFoundError:
  pass

if IN_COLAB:
  source_path = Path('/content/drive/My Drive/Colab Notebooks/CHE-AI-COURSE')
  os.symlink(source_path, shortcut_path)
  shortcut_path = Path(shortcut_path)
  if source_path.exists():
    NOTEBOOK_DIR = shortcut_path / 'Part_4'
    OUTPUT_DIR = NOTEBOOK_DIR / 'outputs' / UNIT_OUTPUT_DIR
    DATA_DIR = NOTEBOOK_DIR / 'data' / SOURCE_DATA_DIR
    MODEL_DIR = OUTPUT_DIR / 'models'
    FIG_DIR = OUTPUT_DIR / 'figs'
  else:
    print(f"⚠️ 找不到路徑雲端CHE-AI-COURSE路徑，請確認自己的雲端資料夾是否正確")
  
else:
  NOTEBOOK_DIR = Path.cwd()
  OUTPUT_DIR = NOTEBOOK_DIR / 'outputs' / UNIT_OUTPUT_DIR
  DATA_DIR = NOTEBOOK_DIR / 'data' / SOURCE_DATA_DIR
  MODEL_DIR = OUTPUT_DIR / 'models'
  FIG_DIR = OUTPUT_DIR / 'figs'

NOTEBOOK_DIR.mkdir(parents=True, exist_ok=True)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
DATA_DIR.mkdir(parents=True, exist_ok=True)
MODEL_DIR.mkdir(parents=True, exist_ok=True)
FIG_DIR.mkdir(parents=True, exist_ok=True)

print(f"\n✓ Notebook工作目錄: {NOTEBOOK_DIR}")
print(f"✓ 數據來源目錄: {DATA_DIR}")
print(f"✓ 結果輸出目錄: {OUTPUT_DIR}")
print(f"✓ 模型輸出目錄: {MODEL_DIR}")
print(f"✓ 圖檔輸出目錄: {FIG_DIR}")

# ========================================
# 檢查 GPU 狀態
# ========================================
print(f"\nTensorFlow Version: {tf.__version__}")
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"✓ 偵測到 GPU：{gpus[0].name}")
    print("  （RNN訓練速度將明顯快於僅用 CPU）")
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
else:
    print("△ 未偵測到 GPU。")
    print("  訓練速度將使用 CPU（RNN在CPU上訓練較慢）")
# Out:
# ✓ 偵測到 Local 環境
#
# ✓ Notebook工作目錄: d:\MyGit\CHE-AI-COURSE\Part_4
# ✓ 數據來源目錄: d:\MyGit\CHE-AI-COURSE\Part_4\data
# ✓ 結果輸出目錄: d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results
# ✓ 模型輸出目錄: d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models
# ✓ 圖檔輸出目錄: d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\figs
#
# TensorFlow Version: 2.10.1
# ✓ 偵測到 GPU：/physical_device:GPU:0
#   （RNN訓練速度將明顯快於僅用 CPU）

# %% [markdown]
# ---
# ## 1. 導入必要套件

# %%
# 基礎套件
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import datetime
import joblib, pickle
import warnings
warnings.filterwarnings('ignore')

# sklearn套件
from sklearn.model_selection import train_test_split, TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# TensorFlow / Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard

print(f"TensorFlow版本: {tf.__version__}")
print(f"Keras版本: {keras.__version__}")

# 設定隨機種子以確保結果可重現
SEED=42
np.random.seed(SEED)
tf.random.set_seed(SEED)
plt.rcParams['axes.unicode_minus'] = False
# Out:
# TensorFlow版本: 2.10.1
# Keras版本: 2.10.0

# %% [markdown]
# ---
# ## 2. 時間序列數據準備
#
# ### 2.1 生成模擬時間序列數據
#
# 我們將生成一個模擬的化工過程時間序列數據集，包含溫度、壓力、流量等變數，目標是預測產品品質。

# %%
def generate_timeseries_data(n_samples=2000, timesteps=30, n_features=10):
    """
    生成模擬的時間序列數據
    
    參數:
        n_samples: 樣本數量
        timesteps: 每個序列的時間步數
        n_features: 每個時間步的特徵數
    
    返回:
        X: 輸入序列 (n_samples, timesteps, n_features)
        y: 目標值 (n_samples,)
    """
    print(f"生成模擬時間序列數據...")
    print(f"  - 樣本數: {n_samples}")
    print(f"  - 時間步數: {timesteps}")
    print(f"  - 特徵數: {n_features}")
    
    # 生成隨機序列數據
    X = np.random.randn(n_samples, timesteps, n_features)
    
    # 添加趨勢和週期性
    for i in range(n_samples):
        trend = np.linspace(0, np.random.randn(), timesteps)
        seasonal = np.sin(2 * np.pi * np.arange(timesteps) / 10) * np.random.rand()
        for j in range(n_features):
            X[i, :, j] += trend + seasonal
    
    # 生成目標值：基於序列的非線性組合
    y = np.zeros(n_samples)
    for i in range(n_samples):
        # 使用最後幾個時間步的平均值和特定特徵
        last_steps = X[i, -5:, :3].mean(axis=0)
        y[i] = (last_steps[0]**2 + last_steps[1] * last_steps[2] + 
                np.sin(last_steps.sum()) + np.random.randn() * 0.1)
    
    print(f"\n數據形狀:")
    print(f"  X: {X.shape}")
    print(f"  y: {y.shape}")
    print(f"\n目標值統計:")
    print(f"  平均值: {y.mean():.4f}")
    print(f"  標準差: {y.std():.4f}")
    print(f"  最小值: {y.min():.4f}")
    print(f"  最大值: {y.max():.4f}")
    
    return X, y

# 生成數據
X, y = generate_timeseries_data(n_samples=2000, timesteps=30, n_features=10)
# Out:
# 生成模擬時間序列數據...
#   - 樣本數: 2000
#   - 時間步數: 30
#   - 特徵數: 10
#
# 數據形狀:
#   X: (2000, 30, 10)
#   y: (2000,)
#
# 目標值統計:
#   平均值: 2.2664
#   標準差: 3.3533
#   最小值: -2.2008
#   最大值: 30.3427

# %% [markdown]
# ### 2.2 數據視覺化
#
# 查看幾個樣本的時間序列模式

# %%
# 視覺化前3個樣本的前3個特徵
fig, axes = plt.subplots(3, 3, figsize=(15, 10))
fig.suptitle('Time series examples (first 3 samples, first 3 features)', fontsize=16)

for i in range(3):
    for j in range(3):
        axes[i, j].plot(X[i, :, j])
        axes[i, j].set_title(f'Sample {i+1}, Feature {j+1}\n(y={y[i]:.4f})')
        axes[i, j].set_xlabel('Time Step')
        axes[i, j].set_ylabel('Value')
        axes[i, j].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(FIG_DIR / 'timeseries_examples.png', dpi=150, bbox_inches='tight')
plt.show()

print("✓ 時間序列範例圖已保存")
# Out:
# ✓ 時間序列範例圖已保存

# %% [markdown]
# ### 2.3 數據分割與標準化
#
# **重要**: 時間序列數據的分割和標準化順序很關鍵！

# %%
# 步驟1: 先分割數據 (不打亂!)
print("分割數據集...")
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.15, random_state=42, shuffle=False  # 時間序列不shuffle
)

X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.176, random_state=42, shuffle=False  # 15%驗證集
)

print(f"\n數據集大小:")
print(f"  訓練集: {X_train.shape[0]} 樣本 ({X_train.shape[0]/len(X)*100:.1f}%)")
print(f"  驗證集: {X_val.shape[0]} 樣本 ({X_val.shape[0]/len(X)*100:.1f}%)")
print(f"  測試集: {X_test.shape[0]} 樣本 ({X_test.shape[0]/len(X)*100:.1f}%)")

# 步驟2: 標準化 (只用訓練集fit)
print("\n標準化數據...")
scaler_X = StandardScaler()
scaler_y = StandardScaler()

# X的標準化 (需要先展平為2D)
X_train_flat = X_train.reshape(-1, X_train.shape[-1])
X_train_scaled = scaler_X.fit_transform(X_train_flat).reshape(X_train.shape)

X_val_flat = X_val.reshape(-1, X_val.shape[-1])
X_val_scaled = scaler_X.transform(X_val_flat).reshape(X_val.shape)

X_test_flat = X_test.reshape(-1, X_test.shape[-1])
X_test_scaled = scaler_X.transform(X_test_flat).reshape(X_test.shape)

# y的標準化
y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, 1)).flatten()
y_val_scaled = scaler_y.transform(y_val.reshape(-1, 1)).flatten()
y_test_scaled = scaler_y.transform(y_test.reshape(-1, 1)).flatten()

print("✓ 標準化完成")
print(f"\n標準化後的統計:")
print(f"  X_train - Mean: {X_train_scaled.mean():.4f}, Std: {X_train_scaled.std():.4f}")
print(f"  y_train - Mean: {y_train_scaled.mean():.4f}, Std: {y_train_scaled.std():.4f}")
# Out:
# 分割數據集...
#
# 數據集大小:
#   訓練集: 1400 樣本 (70.0%)
#   驗證集: 300 樣本 (15.0%)
#   測試集: 300 樣本 (15.0%)
#
# 標準化數據...
# ✓ 標準化完成
#
# 標準化後的統計:
#   X_train - Mean: -0.0000, Std: 1.0000
#   y_train - Mean: -0.0000, Std: 1.0000

# %% [markdown]
# ---
# ## 3. 建立RNN模型
#
# 我們將建立並比較三種模型: SimpleRNN, LSTM, GRU

# %% [markdown]
# ### 3.1 模型1: SimpleRNN (基礎RNN)

# %%
# 建立SimpleRNN模型
input_shape = (X_train_scaled.shape[1], X_train_scaled.shape[2])
model_rnn = Sequential([
    SimpleRNN(64, return_sequences=True, input_shape=input_shape),
    SimpleRNN(32),
    Dense(16, activation='relu'),
    Dense(1)
], name='SimpleRNN')
model_rnn.summary()

# 計算參數量
total_params = model_rnn.count_params()
print(f"\n✓ SimpleRNN模型總參數量: {total_params:,}")
# Out:
# Model: "SimpleRNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 30, 64)            4800
#
#  simple_rnn_1 (SimpleRNN)    (None, 32)                3104
#
#  dense (Dense)               (None, 16)                528
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 8,449
# Trainable params: 8,449
# Non-trainable params: 0
# _________________________________________________________________
#
# ✓ SimpleRNN模型總參數量: 8,449

# %% [markdown]
# ### 3.2 模型2: LSTM

# %%
# 建立LSTM模型
model_lstm = Sequential([
    LSTM(128, return_sequences=True, input_shape=input_shape),
    LSTM(64),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(1)
], name='LSTM')
model_lstm.summary()

total_params = model_lstm.count_params()
print(f"\n✓ LSTM模型總參數量: {total_params:,}")
# Out:
# Model: "LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 128)           71168
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 122,689
# Trainable params: 122,689
# Non-trainable params: 0
# _________________________________________________________________
#
# ✓ LSTM模型總參數量: 122,689

# %% [markdown]
# ### 3.3 模型3: GRU

# %%
# 建立GRU模型
model_gru = Sequential([
    GRU(128, return_sequences=True, input_shape=input_shape),
    GRU(64),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(1)
], name='GRU')
model_gru.summary()
total_params = model_gru.count_params()
print(f"\n✓ GRU模型總參數量: {total_params:,}")
# Out:
# Model: "GRU"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 30, 128)           53760
#
#  gru_1 (GRU)                 (None, 64)                37248
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 93,121
# Trainable params: 93,121
# Non-trainable params: 0
# _________________________________________________________________
#
# ✓ GRU模型總參數量: 93,121

# %% [markdown]
# ### 3.4 參數量比較

# %%
# 比較三個模型的參數量
params_comparison = {
    'SimpleRNN': model_rnn.count_params(),
    'LSTM': model_lstm.count_params(),
    'GRU': model_gru.count_params()
}

print("\n=== 模型參數量比較 ===")
for model_name, params in params_comparison.items():
    print(f"{model_name:12s}: {params:>10,} parameters")

# 視覺化
plt.figure(figsize=(10, 6))
plt.bar(params_comparison.keys(), params_comparison.values(), 
        color=['skyblue', 'coral', 'lightgreen'])
plt.ylabel('Parameters Count')
plt.title('Model Parameters Comparison')
plt.grid(axis='y', alpha=0.3)
for i, (name, val) in enumerate(params_comparison.items()):
    plt.text(i, val, f'{val:,}', ha='center', va='bottom')
plt.tight_layout()
plt.savefig(FIG_DIR / 'model_params_comparison.png', dpi=150)
plt.show()
# Out:
# === 模型參數量比較 ===
# SimpleRNN   :      8,449 parameters
# LSTM        :    122,689 parameters
# GRU         :     93,121 parameters

# %% [markdown]
# ---
# ## 4. 設定Callbacks
# Callbacks設定
# - EarlyStopping (patience=30)
# - ModelCheckpoint (保存最佳模型)
# - ReduceLROnPlateau (動態調整學習率)

# %%
# 設定SimpleRNN callbacks
callbacks_rnn = [
    EarlyStopping(
        monitor='val_loss',
        patience=30,
        restore_best_weights=True,
        verbose=1
    ),
    ModelCheckpoint(
        filepath=str(MODEL_DIR / 'best_simple_rnn_model.h5'),
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=15,
        min_lr=1e-7,
        verbose=1
    )
]

# %%
# 設定LSTM callbacks
callbacks_lstm = [
    EarlyStopping(
        monitor='val_loss',
        patience=30,
        restore_best_weights=True,
        verbose=1
    ),
    ModelCheckpoint(
        filepath=str(MODEL_DIR / 'best_lstm_model.h5'),
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=15,
        min_lr=1e-7,
        verbose=1
    )
]

# %%
# 設定GRU callbacks
callbacks_gru = [
    EarlyStopping(
        monitor='val_loss',
        patience=30,
        restore_best_weights=True,
        verbose=1
    ),
    ModelCheckpoint(
        filepath=str(MODEL_DIR / 'best_gru_model.h5'),
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=15,
        min_lr=1e-7,
        verbose=1
    )
]

# %% [markdown]
# ---
# ## 5. 模型編譯與訓練

# %% [markdown]
# ### 5.1 訓練SimpleRNN模型

# %%
print("開始訓練SimpleRNN模型...\n")

# 編譯SimpleRNN模型
model_rnn.compile(
    optimizer=Adam(learning_rate=0.001, clipnorm=1.0),
    loss='mse',
    metrics=['mae', 'RootMeanSquaredError']
)


# 訓練
history_rnn = model_rnn.fit(
    X_train_scaled, y_train_scaled,
    epochs=200,
    batch_size=32,
    validation_data=(X_val_scaled, y_val_scaled),
    callbacks=callbacks_rnn,
    shuffle=False,
    verbose=1
)

print("\n✓ SimpleRNN訓練完成！")
# Out:
# 開始訓練SimpleRNN模型...
#
# Epoch 1/200
# 44/44 [==============================] - ETA: 0s - loss: 0.7305 - mae: 0.5797 - root_mean_squared_error: 0.8547
# Epoch 1: val_loss improved from inf to 0.38351, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_simple_rnn_model.h5
# 44/44 [==============================] - 5s 60ms/step - loss: 0.7305 - mae: 0.5797 - root_mean_squared_error: 0.8547 - val_loss: 0.3835 - val_mae: 0.4355 - val_root_mean_squared_error: 0.6193 - lr: 0.0010
# Epoch 2/200
# 44/44 [==============================] - ETA: 0s - loss: 0.3261 - mae: 0.3566 - root_mean_squared_error: 0.5710
# Epoch 2: val_loss improved from 0.38351 to 0.19720, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_simple_rnn_model.h5
# 44/44 [==============================] - 2s 56ms/step - loss: 0.3261 - mae: 0.3566 - root_mean_squared_error: 0.5710 - val_loss: 0.1972 - val_mae: 0.3168 - val_root_mean_squared_error: 0.4441 - lr: 0.0010
# Epoch 3/200
# 44/44 [==============================] - ETA: 0s - loss: 0.2013 - mae: 0.2635 - root_mean_squared_error: 0.4487
# Epoch 3: val_loss improved from 0.19720 to 0.13218, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_simple_rnn_model.h5
# 44/44 [==============================] - 3s 58ms/step - loss: 0.2013 - mae: 0.2635 - root_mean_squared_error: 0.4487 - val_loss: 0.1322 - val_mae: 0.2626 - val_root_mean_squared_error: 0.3636 - lr: 0.0010
# Epoch 4/200
# 44/44 [==============================] - ETA: 0s - loss: 0.1458 - mae: 0.2235 - root_mean_squared_error: 0.3818
# Epoch 4: val_loss improved from 0.13218 to 0.11055, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_simple_rnn_model.h5
# 44/44 [==============================] - 3s 59ms/step - loss: 0.1458 - mae: 0.2235 - root_mean_squared_error: 0.3818 - val_loss: 0.1105 - val_mae: 0.2435 - val_root_mean_squared_error: 0.3325 - lr: 0.0010
# Epoch 5/200
# 44/44 [==============================] - ETA: 0s - loss: 0.1208 - mae: 0.2061 - root_mean_squared_error: 0.3475
# Epoch 5: val_loss improved from 0.11055 to 0.09080, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_simple_rnn_model.h5
# 44/44 [==============================] - 3s 59ms/step - loss: 0.1208 - mae: 0.2061 - root_mean_squared_error: 0.3475 - val_loss: 0.0908 - val_mae: 0.2281 - val_root_mean_squared_error: 0.3013 - lr: 0.0010
# Epoch 6/200
# 44/44 [==============================] - ETA: 0s - loss: 0.1030 - mae: 0.1939 - root_mean_squared_error: 0.3210
# Epoch 6: val_loss improved from 0.09080 to 0.08608, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_simple_rnn_model.h5
# 44/44 [==============================] - 3s 58ms/step - loss: 0.1030 - mae: 0.1939 - root_mean_squared_error: 0.3210 - val_loss: 0.0861 - val_mae: 0.2233 - val_root_mean_squared_error: 0.2934 - lr: 0.0010
# Epoch 7/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0901 - mae: 0.1824 - root_mean_squared_error: 0.3002
# Epoch 7: val_loss improved from 0.08608 to 0.07980, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_simple_rnn_model.h5
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0901 - mae: 0.1824 - root_mean_squared_error: 0.3002 - val_loss: 0.0798 - val_mae: 0.2176 - val_root_mean_squared_error: 0.2825 - lr: 0.0010
# Epoch 8/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0806 - mae: 0.1746 - root_mean_squared_error: 0.2840
# Epoch 8: val_loss improved from 0.07980 to 0.07726, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_simple_rnn_model.h5
# 44/44 [==============================] - 3s 59ms/step - loss: 0.0806 - mae: 0.1746 - root_mean_squared_error: 0.2840 - val_loss: 0.0773 - val_mae: 0.2137 - val_root_mean_squared_error: 0.2780 - lr: 0.0010
# Epoch 9/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0730 - mae: 0.1688 - root_mean_squared_error: 0.2702
# Epoch 9: val_loss improved from 0.07726 to 0.07532, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_simple_rnn_model.h5
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0730 - mae: 0.1688 - root_mean_squared_error: 0.2702 - val_loss: 0.0753 - val_mae: 0.2121 - val_root_mean_squared_error: 0.2744 - lr: 0.0010
# Epoch 10/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0675 - mae: 0.1640 - root_mean_squared_error: 0.2598
# Epoch 10: val_loss improved from 0.07532 to 0.07484, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_simple_rnn_model.h5
# 44/44 [==============================] - 3s 59ms/step - loss: 0.0675 - mae: 0.1640 - root_mean_squared_error: 0.2598 - val_loss: 0.0748 - val_mae: 0.2116 - val_root_mean_squared_error: 0.2736 - lr: 0.0010
# Epoch 11/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0610 - mae: 0.1565 - root_mean_squared_error: 0.2470
# Epoch 11: val_loss did not improve from 0.07484
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0610 - mae: 0.1565 - root_mean_squared_error: 0.2470 - val_loss: 0.0917 - val_mae: 0.2321 - val_root_mean_squared_error: 0.3028 - lr: 0.0010
# Epoch 12/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0586 - mae: 0.1548 - root_mean_squared_error: 0.2420
# Epoch 12: val_loss did not improve from 0.07484
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0586 - mae: 0.1548 - root_mean_squared_error: 0.2420 - val_loss: 0.0905 - val_mae: 0.2323 - val_root_mean_squared_error: 0.3009 - lr: 0.0010
# Epoch 13/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0605 - mae: 0.1572 - root_mean_squared_error: 0.2459
# Epoch 13: val_loss improved from 0.07484 to 0.06631, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_simple_rnn_model.h5
# 44/44 [==============================] - 3s 59ms/step - loss: 0.0605 - mae: 0.1572 - root_mean_squared_error: 0.2459 - val_loss: 0.0663 - val_mae: 0.2016 - val_root_mean_squared_error: 0.2575 - lr: 0.0010
# Epoch 14/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0602 - mae: 0.1575 - root_mean_squared_error: 0.2453
# Epoch 14: val_loss improved from 0.06631 to 0.05852, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_simple_rnn_model.h5
# 44/44 [==============================] - 3s 59ms/step - loss: 0.0602 - mae: 0.1575 - root_mean_squared_error: 0.2453 - val_loss: 0.0585 - val_mae: 0.1892 - val_root_mean_squared_error: 0.2419 - lr: 0.0010
# Epoch 15/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0502 - mae: 0.1459 - root_mean_squared_error: 0.2240
# Epoch 15: val_loss did not improve from 0.05852
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0502 - mae: 0.1459 - root_mean_squared_error: 0.2240 - val_loss: 0.0589 - val_mae: 0.1879 - val_root_mean_squared_error: 0.2427 - lr: 0.0010
# Epoch 16/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0449 - mae: 0.1398 - root_mean_squared_error: 0.2119
# Epoch 16: val_loss improved from 0.05852 to 0.05559, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_simple_rnn_model.h5
# 44/44 [==============================] - 3s 59ms/step - loss: 0.0449 - mae: 0.1398 - root_mean_squared_error: 0.2119 - val_loss: 0.0556 - val_mae: 0.1846 - val_root_mean_squared_error: 0.2358 - lr: 0.0010
# Epoch 17/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0391 - mae: 0.1312 - root_mean_squared_error: 0.1976
# Epoch 17: val_loss did not improve from 0.05559
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0391 - mae: 0.1312 - root_mean_squared_error: 0.1976 - val_loss: 0.0580 - val_mae: 0.1882 - val_root_mean_squared_error: 0.2409 - lr: 0.0010
# Epoch 18/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0337 - mae: 0.1227 - root_mean_squared_error: 0.1837
# Epoch 18: val_loss did not improve from 0.05559
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0337 - mae: 0.1227 - root_mean_squared_error: 0.1837 - val_loss: 0.0559 - val_mae: 0.1835 - val_root_mean_squared_error: 0.2365 - lr: 0.0010
# Epoch 19/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0304 - mae: 0.1168 - root_mean_squared_error: 0.1744
# Epoch 19: val_loss did not improve from 0.05559
# 44/44 [==============================] - 3s 57ms/step - loss: 0.0304 - mae: 0.1168 - root_mean_squared_error: 0.1744 - val_loss: 0.0604 - val_mae: 0.1890 - val_root_mean_squared_error: 0.2458 - lr: 0.0010
# Epoch 20/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0287 - mae: 0.1144 - root_mean_squared_error: 0.1695
# Epoch 20: val_loss did not improve from 0.05559
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0287 - mae: 0.1144 - root_mean_squared_error: 0.1695 - val_loss: 0.0575 - val_mae: 0.1845 - val_root_mean_squared_error: 0.2397 - lr: 0.0010
# Epoch 21/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0259 - mae: 0.1095 - root_mean_squared_error: 0.1609
# Epoch 21: val_loss did not improve from 0.05559
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0259 - mae: 0.1095 - root_mean_squared_error: 0.1609 - val_loss: 0.0619 - val_mae: 0.1879 - val_root_mean_squared_error: 0.2489 - lr: 0.0010
# Epoch 22/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0262 - mae: 0.1115 - root_mean_squared_error: 0.1617
# Epoch 22: val_loss did not improve from 0.05559
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0262 - mae: 0.1115 - root_mean_squared_error: 0.1617 - val_loss: 0.0661 - val_mae: 0.1939 - val_root_mean_squared_error: 0.2570 - lr: 0.0010
# Epoch 23/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0267 - mae: 0.1149 - root_mean_squared_error: 0.1633
# Epoch 23: val_loss did not improve from 0.05559
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0267 - mae: 0.1149 - root_mean_squared_error: 0.1633 - val_loss: 0.0813 - val_mae: 0.2105 - val_root_mean_squared_error: 0.2852 - lr: 0.0010
# Epoch 24/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0308 - mae: 0.1229 - root_mean_squared_error: 0.1756
# Epoch 24: val_loss did not improve from 0.05559
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0308 - mae: 0.1229 - root_mean_squared_error: 0.1756 - val_loss: 0.0876 - val_mae: 0.2236 - val_root_mean_squared_error: 0.2960 - lr: 0.0010
# Epoch 25/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0478 - mae: 0.1447 - root_mean_squared_error: 0.2186
# Epoch 25: val_loss did not improve from 0.05559
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0478 - mae: 0.1447 - root_mean_squared_error: 0.2186 - val_loss: 0.0843 - val_mae: 0.2283 - val_root_mean_squared_error: 0.2903 - lr: 0.0010
# Epoch 26/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0540 - mae: 0.1486 - root_mean_squared_error: 0.2324
# Epoch 26: val_loss improved from 0.05559 to 0.04727, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_simple_rnn_model.h5
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0540 - mae: 0.1486 - root_mean_squared_error: 0.2324 - val_loss: 0.0473 - val_mae: 0.1711 - val_root_mean_squared_error: 0.2174 - lr: 0.0010
# Epoch 27/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0292 - mae: 0.1099 - root_mean_squared_error: 0.1708
# Epoch 27: val_loss improved from 0.04727 to 0.04592, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_simple_rnn_model.h5
# 44/44 [==============================] - 3s 59ms/step - loss: 0.0292 - mae: 0.1099 - root_mean_squared_error: 0.1708 - val_loss: 0.0459 - val_mae: 0.1677 - val_root_mean_squared_error: 0.2143 - lr: 0.0010
# Epoch 28/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0225 - mae: 0.0978 - root_mean_squared_error: 0.1501
# Epoch 28: val_loss improved from 0.04592 to 0.04426, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_simple_rnn_model.h5
# 44/44 [==============================] - 3s 59ms/step - loss: 0.0225 - mae: 0.0978 - root_mean_squared_error: 0.1501 - val_loss: 0.0443 - val_mae: 0.1641 - val_root_mean_squared_error: 0.2104 - lr: 0.0010
# Epoch 29/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0192 - mae: 0.0911 - root_mean_squared_error: 0.1385
# Epoch 29: val_loss improved from 0.04426 to 0.04380, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_simple_rnn_model.h5
# 44/44 [==============================] - 3s 59ms/step - loss: 0.0192 - mae: 0.0911 - root_mean_squared_error: 0.1385 - val_loss: 0.0438 - val_mae: 0.1615 - val_root_mean_squared_error: 0.2093 - lr: 0.0010
# Epoch 30/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0174 - mae: 0.0870 - root_mean_squared_error: 0.1321
# Epoch 30: val_loss improved from 0.04380 to 0.04265, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_simple_rnn_model.h5
# 44/44 [==============================] - 3s 59ms/step - loss: 0.0174 - mae: 0.0870 - root_mean_squared_error: 0.1321 - val_loss: 0.0426 - val_mae: 0.1598 - val_root_mean_squared_error: 0.2065 - lr: 0.0010
# Epoch 31/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0160 - mae: 0.0849 - root_mean_squared_error: 0.1264
# Epoch 31: val_loss did not improve from 0.04265
# 44/44 [==============================] - 2s 53ms/step - loss: 0.0160 - mae: 0.0849 - root_mean_squared_error: 0.1264 - val_loss: 0.0434 - val_mae: 0.1609 - val_root_mean_squared_error: 0.2083 - lr: 0.0010
# Epoch 32/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0152 - mae: 0.0835 - root_mean_squared_error: 0.1231
# Epoch 32: val_loss did not improve from 0.04265
# 44/44 [==============================] - 2s 56ms/step - loss: 0.0152 - mae: 0.0835 - root_mean_squared_error: 0.1231 - val_loss: 0.0468 - val_mae: 0.1653 - val_root_mean_squared_error: 0.2163 - lr: 0.0010
# Epoch 33/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0148 - mae: 0.0830 - root_mean_squared_error: 0.1215
# Epoch 33: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 57ms/step - loss: 0.0148 - mae: 0.0830 - root_mean_squared_error: 0.1215 - val_loss: 0.0521 - val_mae: 0.1745 - val_root_mean_squared_error: 0.2282 - lr: 0.0010
# Epoch 34/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0153 - mae: 0.0858 - root_mean_squared_error: 0.1237
# Epoch 34: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0153 - mae: 0.0858 - root_mean_squared_error: 0.1237 - val_loss: 0.0640 - val_mae: 0.1925 - val_root_mean_squared_error: 0.2529 - lr: 0.0010
# Epoch 35/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0182 - mae: 0.0948 - root_mean_squared_error: 0.1350
# Epoch 35: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0182 - mae: 0.0948 - root_mean_squared_error: 0.1350 - val_loss: 0.0840 - val_mae: 0.2191 - val_root_mean_squared_error: 0.2898 - lr: 0.0010
# Epoch 36/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0247 - mae: 0.1108 - root_mean_squared_error: 0.1571
# Epoch 36: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0247 - mae: 0.1108 - root_mean_squared_error: 0.1571 - val_loss: 0.1202 - val_mae: 0.2603 - val_root_mean_squared_error: 0.3467 - lr: 0.0010
# Epoch 37/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0383 - mae: 0.1329 - root_mean_squared_error: 0.1958
# Epoch 37: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0383 - mae: 0.1329 - root_mean_squared_error: 0.1958 - val_loss: 0.0520 - val_mae: 0.1742 - val_root_mean_squared_error: 0.2281 - lr: 0.0010
# Epoch 38/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0343 - mae: 0.1275 - root_mean_squared_error: 0.1852
# Epoch 38: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0343 - mae: 0.1275 - root_mean_squared_error: 0.1852 - val_loss: 0.0469 - val_mae: 0.1684 - val_root_mean_squared_error: 0.2165 - lr: 0.0010
# Epoch 39/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0275 - mae: 0.1169 - root_mean_squared_error: 0.1658
# Epoch 39: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0275 - mae: 0.1169 - root_mean_squared_error: 0.1658 - val_loss: 0.0483 - val_mae: 0.1690 - val_root_mean_squared_error: 0.2198 - lr: 0.0010
# Epoch 40/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0195 - mae: 0.1004 - root_mean_squared_error: 0.1395
# Epoch 40: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 59ms/step - loss: 0.0195 - mae: 0.1004 - root_mean_squared_error: 0.1395 - val_loss: 0.0653 - val_mae: 0.1943 - val_root_mean_squared_error: 0.2556 - lr: 0.0010
# Epoch 41/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0167 - mae: 0.0901 - root_mean_squared_error: 0.1293
# Epoch 41: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0167 - mae: 0.0901 - root_mean_squared_error: 0.1293 - val_loss: 0.0806 - val_mae: 0.2112 - val_root_mean_squared_error: 0.2839 - lr: 0.0010
# Epoch 42/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0191 - mae: 0.0981 - root_mean_squared_error: 0.1382
# Epoch 42: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0191 - mae: 0.0981 - root_mean_squared_error: 0.1382 - val_loss: 0.0678 - val_mae: 0.1941 - val_root_mean_squared_error: 0.2605 - lr: 0.0010
# Epoch 43/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0244 - mae: 0.1097 - root_mean_squared_error: 0.1561
# Epoch 43: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0244 - mae: 0.1097 - root_mean_squared_error: 0.1561 - val_loss: 0.0849 - val_mae: 0.2168 - val_root_mean_squared_error: 0.2914 - lr: 0.0010
# Epoch 44/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0235 - mae: 0.1072 - root_mean_squared_error: 0.1534
# Epoch 44: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0235 - mae: 0.1072 - root_mean_squared_error: 0.1534 - val_loss: 0.1381 - val_mae: 0.2716 - val_root_mean_squared_error: 0.3716 - lr: 0.0010
# Epoch 45/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0300 - mae: 0.1216 - root_mean_squared_error: 0.1732
# Epoch 45: val_loss did not improve from 0.04265
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0300 - mae: 0.1216 - root_mean_squared_error: 0.1732 - val_loss: 0.1973 - val_mae: 0.3231 - val_root_mean_squared_error: 0.4442 - lr: 0.0010
# Epoch 46/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0458 - mae: 0.1477 - root_mean_squared_error: 0.2139
# Epoch 46: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 57ms/step - loss: 0.0458 - mae: 0.1477 - root_mean_squared_error: 0.2139 - val_loss: 0.0503 - val_mae: 0.1731 - val_root_mean_squared_error: 0.2242 - lr: 5.0000e-04
# Epoch 47/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0247 - mae: 0.1077 - root_mean_squared_error: 0.1573
# Epoch 47: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0247 - mae: 0.1077 - root_mean_squared_error: 0.1573 - val_loss: 0.0465 - val_mae: 0.1666 - val_root_mean_squared_error: 0.2156 - lr: 5.0000e-04
# Epoch 48/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0195 - mae: 0.0950 - root_mean_squared_error: 0.1397
# Epoch 48: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0195 - mae: 0.0950 - root_mean_squared_error: 0.1397 - val_loss: 0.0451 - val_mae: 0.1646 - val_root_mean_squared_error: 0.2123 - lr: 5.0000e-04
# Epoch 49/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0159 - mae: 0.0851 - root_mean_squared_error: 0.1262
# Epoch 49: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0159 - mae: 0.0851 - root_mean_squared_error: 0.1262 - val_loss: 0.0451 - val_mae: 0.1652 - val_root_mean_squared_error: 0.2124 - lr: 5.0000e-04
# Epoch 50/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0141 - mae: 0.0797 - root_mean_squared_error: 0.1189
# Epoch 50: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 57ms/step - loss: 0.0141 - mae: 0.0797 - root_mean_squared_error: 0.1189 - val_loss: 0.0447 - val_mae: 0.1642 - val_root_mean_squared_error: 0.2114 - lr: 5.0000e-04
# Epoch 51/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0127 - mae: 0.0757 - root_mean_squared_error: 0.1128
# Epoch 51: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 57ms/step - loss: 0.0127 - mae: 0.0757 - root_mean_squared_error: 0.1128 - val_loss: 0.0447 - val_mae: 0.1638 - val_root_mean_squared_error: 0.2114 - lr: 5.0000e-04
# Epoch 52/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0116 - mae: 0.0722 - root_mean_squared_error: 0.1079
# Epoch 52: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0116 - mae: 0.0722 - root_mean_squared_error: 0.1079 - val_loss: 0.0447 - val_mae: 0.1638 - val_root_mean_squared_error: 0.2114 - lr: 5.0000e-04
# Epoch 53/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0109 - mae: 0.0697 - root_mean_squared_error: 0.1042
# Epoch 53: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0109 - mae: 0.0697 - root_mean_squared_error: 0.1042 - val_loss: 0.0448 - val_mae: 0.1640 - val_root_mean_squared_error: 0.2117 - lr: 5.0000e-04
# Epoch 54/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0101 - mae: 0.0669 - root_mean_squared_error: 0.1005
# Epoch 54: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0101 - mae: 0.0669 - root_mean_squared_error: 0.1005 - val_loss: 0.0450 - val_mae: 0.1639 - val_root_mean_squared_error: 0.2120 - lr: 5.0000e-04
# Epoch 55/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0095 - mae: 0.0650 - root_mean_squared_error: 0.0977
# Epoch 55: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0095 - mae: 0.0650 - root_mean_squared_error: 0.0977 - val_loss: 0.0450 - val_mae: 0.1639 - val_root_mean_squared_error: 0.2121 - lr: 5.0000e-04
# Epoch 56/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0089 - mae: 0.0623 - root_mean_squared_error: 0.0943
# Epoch 56: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0089 - mae: 0.0623 - root_mean_squared_error: 0.0943 - val_loss: 0.0453 - val_mae: 0.1642 - val_root_mean_squared_error: 0.2129 - lr: 5.0000e-04
# Epoch 57/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0084 - mae: 0.0606 - root_mean_squared_error: 0.0918
# Epoch 57: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0084 - mae: 0.0606 - root_mean_squared_error: 0.0918 - val_loss: 0.0451 - val_mae: 0.1641 - val_root_mean_squared_error: 0.2124 - lr: 5.0000e-04
# Epoch 58/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0080 - mae: 0.0589 - root_mean_squared_error: 0.0897
# Epoch 58: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0080 - mae: 0.0589 - root_mean_squared_error: 0.0897 - val_loss: 0.0453 - val_mae: 0.1643 - val_root_mean_squared_error: 0.2129 - lr: 5.0000e-04
# Epoch 59/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0077 - mae: 0.0576 - root_mean_squared_error: 0.0876
# Epoch 59: val_loss did not improve from 0.04265
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0077 - mae: 0.0576 - root_mean_squared_error: 0.0876 - val_loss: 0.0451 - val_mae: 0.1640 - val_root_mean_squared_error: 0.2123 - lr: 5.0000e-04
# Epoch 60/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0073 - mae: 0.0561 - root_mean_squared_error: 0.0856Restoring model weights from the end of the best epoch: 30.
#
# Epoch 60: val_loss did not improve from 0.04265
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0073 - mae: 0.0561 - root_mean_squared_error: 0.0856 - val_loss: 0.0456 - val_mae: 0.1647 - val_root_mean_squared_error: 0.2136 - lr: 5.0000e-04
# Epoch 60: early stopping
#
# ✓ SimpleRNN訓練完成！

# %% [markdown]
# ### 5.2 訓練LSTM模型

# %%
print("開始訓練LSTM模型...\n")

# 編譯LSTM模型
model_lstm.compile(
    optimizer=Adam(learning_rate=0.001, clipnorm=1.0), # 梯度裁剪，防止梯度爆炸
    loss='mse',
    metrics=['mae', 'RootMeanSquaredError']
)

# 訓練
history_lstm = model_lstm.fit(
    X_train_scaled, y_train_scaled,
    epochs=200,
    batch_size=32,
    validation_data=(X_val_scaled, y_val_scaled),
    callbacks=callbacks_lstm,
    shuffle=False,  # 時間序列不打亂！
    verbose=1
)

print("\n✓ LSTM訓練完成！")
# Out:
# 開始訓練LSTM模型...
#
# Epoch 1/200
# 43/44 [============================>.] - ETA: 0s - loss: 0.4228 - mae: 0.4594 - root_mean_squared_error: 0.6502
# Epoch 1: val_loss improved from inf to 0.18496, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 6s 35ms/step - loss: 0.4178 - mae: 0.4568 - root_mean_squared_error: 0.6464 - val_loss: 0.1850 - val_mae: 0.3194 - val_root_mean_squared_error: 0.4301 - lr: 0.0010
# Epoch 2/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.1996 - mae: 0.3045 - root_mean_squared_error: 0.4468
# Epoch 2: val_loss improved from 0.18496 to 0.10870, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 19ms/step - loss: 0.2102 - mae: 0.3053 - root_mean_squared_error: 0.4584 - val_loss: 0.1087 - val_mae: 0.2459 - val_root_mean_squared_error: 0.3297 - lr: 0.0010
# Epoch 3/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.1237 - mae: 0.2479 - root_mean_squared_error: 0.3517
# Epoch 3: val_loss improved from 0.10870 to 0.06287, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 18ms/step - loss: 0.1262 - mae: 0.2499 - root_mean_squared_error: 0.3553 - val_loss: 0.0629 - val_mae: 0.1931 - val_root_mean_squared_error: 0.2507 - lr: 0.0010
# Epoch 4/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0886 - mae: 0.2117 - root_mean_squared_error: 0.2976
# Epoch 4: val_loss improved from 0.06287 to 0.06153, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0950 - mae: 0.2147 - root_mean_squared_error: 0.3082 - val_loss: 0.0615 - val_mae: 0.1847 - val_root_mean_squared_error: 0.2480 - lr: 0.0010
# Epoch 5/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0971 - mae: 0.2106 - root_mean_squared_error: 0.3115
# Epoch 5: val_loss improved from 0.06153 to 0.04730, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 18ms/step - loss: 0.1040 - mae: 0.2133 - root_mean_squared_error: 0.3225 - val_loss: 0.0473 - val_mae: 0.1637 - val_root_mean_squared_error: 0.2175 - lr: 0.0010
# Epoch 6/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0818 - mae: 0.1920 - root_mean_squared_error: 0.2860
# Epoch 6: val_loss did not improve from 0.04730
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0818 - mae: 0.1920 - root_mean_squared_error: 0.2860 - val_loss: 0.0490 - val_mae: 0.1686 - val_root_mean_squared_error: 0.2214 - lr: 0.0010
# Epoch 7/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0629 - mae: 0.1776 - root_mean_squared_error: 0.2509
# Epoch 7: val_loss improved from 0.04730 to 0.04555, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0639 - mae: 0.1790 - root_mean_squared_error: 0.2528 - val_loss: 0.0456 - val_mae: 0.1481 - val_root_mean_squared_error: 0.2134 - lr: 0.0010
# Epoch 8/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0591 - mae: 0.1697 - root_mean_squared_error: 0.2431
# Epoch 8: val_loss improved from 0.04555 to 0.04467, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0617 - mae: 0.1720 - root_mean_squared_error: 0.2484 - val_loss: 0.0447 - val_mae: 0.1568 - val_root_mean_squared_error: 0.2114 - lr: 0.0010
# Epoch 9/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0619 - mae: 0.1726 - root_mean_squared_error: 0.2489
# Epoch 9: val_loss did not improve from 0.04467
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0639 - mae: 0.1743 - root_mean_squared_error: 0.2527 - val_loss: 0.0544 - val_mae: 0.1608 - val_root_mean_squared_error: 0.2332 - lr: 0.0010
# Epoch 10/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0675 - mae: 0.1765 - root_mean_squared_error: 0.2597
# Epoch 10: val_loss did not improve from 0.04467
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0678 - mae: 0.1770 - root_mean_squared_error: 0.2603 - val_loss: 0.0466 - val_mae: 0.1490 - val_root_mean_squared_error: 0.2158 - lr: 0.0010
# Epoch 11/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0627 - mae: 0.1707 - root_mean_squared_error: 0.2505
# Epoch 11: val_loss did not improve from 0.04467
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0609 - mae: 0.1687 - root_mean_squared_error: 0.2468 - val_loss: 0.0667 - val_mae: 0.1706 - val_root_mean_squared_error: 0.2582 - lr: 0.0010
# Epoch 12/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0575 - mae: 0.1630 - root_mean_squared_error: 0.2398
# Epoch 12: val_loss improved from 0.04467 to 0.03334, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0566 - mae: 0.1624 - root_mean_squared_error: 0.2378 - val_loss: 0.0333 - val_mae: 0.1353 - val_root_mean_squared_error: 0.1826 - lr: 0.0010
# Epoch 13/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0480 - mae: 0.1529 - root_mean_squared_error: 0.2191
# Epoch 13: val_loss did not improve from 0.03334
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0501 - mae: 0.1548 - root_mean_squared_error: 0.2238 - val_loss: 0.0368 - val_mae: 0.1355 - val_root_mean_squared_error: 0.1918 - lr: 0.0010
# Epoch 14/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0609 - mae: 0.1645 - root_mean_squared_error: 0.2469
# Epoch 14: val_loss did not improve from 0.03334
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0609 - mae: 0.1645 - root_mean_squared_error: 0.2469 - val_loss: 0.0535 - val_mae: 0.1619 - val_root_mean_squared_error: 0.2312 - lr: 0.0010
# Epoch 15/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0520 - mae: 0.1593 - root_mean_squared_error: 0.2280
# Epoch 15: val_loss did not improve from 0.03334
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0511 - mae: 0.1580 - root_mean_squared_error: 0.2261 - val_loss: 0.0526 - val_mae: 0.1619 - val_root_mean_squared_error: 0.2293 - lr: 0.0010
# Epoch 16/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0433 - mae: 0.1512 - root_mean_squared_error: 0.2081
# Epoch 16: val_loss did not improve from 0.03334
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0487 - mae: 0.1535 - root_mean_squared_error: 0.2208 - val_loss: 0.0542 - val_mae: 0.1540 - val_root_mean_squared_error: 0.2328 - lr: 0.0010
# Epoch 17/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0661 - mae: 0.1660 - root_mean_squared_error: 0.2571
# Epoch 17: val_loss improved from 0.03334 to 0.02767, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0638 - mae: 0.1635 - root_mean_squared_error: 0.2526 - val_loss: 0.0277 - val_mae: 0.1209 - val_root_mean_squared_error: 0.1663 - lr: 0.0010
# Epoch 18/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0563 - mae: 0.1584 - root_mean_squared_error: 0.2373
# Epoch 18: val_loss did not improve from 0.02767
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0563 - mae: 0.1586 - root_mean_squared_error: 0.2372 - val_loss: 0.0475 - val_mae: 0.1483 - val_root_mean_squared_error: 0.2179 - lr: 0.0010
# Epoch 19/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0479 - mae: 0.1563 - root_mean_squared_error: 0.2188
# Epoch 19: val_loss did not improve from 0.02767
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0473 - mae: 0.1556 - root_mean_squared_error: 0.2176 - val_loss: 0.0329 - val_mae: 0.1333 - val_root_mean_squared_error: 0.1815 - lr: 0.0010
# Epoch 20/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0501 - mae: 0.1522 - root_mean_squared_error: 0.2239
# Epoch 20: val_loss did not improve from 0.02767
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0501 - mae: 0.1522 - root_mean_squared_error: 0.2239 - val_loss: 0.0424 - val_mae: 0.1436 - val_root_mean_squared_error: 0.2060 - lr: 0.0010
# Epoch 21/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0538 - mae: 0.1560 - root_mean_squared_error: 0.2319
# Epoch 21: val_loss did not improve from 0.02767
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0538 - mae: 0.1560 - root_mean_squared_error: 0.2319 - val_loss: 0.0506 - val_mae: 0.1510 - val_root_mean_squared_error: 0.2250 - lr: 0.0010
# Epoch 22/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0485 - mae: 0.1527 - root_mean_squared_error: 0.2203
# Epoch 22: val_loss did not improve from 0.02767
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0485 - mae: 0.1527 - root_mean_squared_error: 0.2203 - val_loss: 0.0437 - val_mae: 0.1405 - val_root_mean_squared_error: 0.2089 - lr: 0.0010
# Epoch 23/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0464 - mae: 0.1480 - root_mean_squared_error: 0.2154
# Epoch 23: val_loss did not improve from 0.02767
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0484 - mae: 0.1489 - root_mean_squared_error: 0.2199 - val_loss: 0.0397 - val_mae: 0.1444 - val_root_mean_squared_error: 0.1992 - lr: 0.0010
# Epoch 24/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0474 - mae: 0.1499 - root_mean_squared_error: 0.2177
# Epoch 24: val_loss did not improve from 0.02767
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0460 - mae: 0.1476 - root_mean_squared_error: 0.2144 - val_loss: 0.0294 - val_mae: 0.1239 - val_root_mean_squared_error: 0.1716 - lr: 0.0010
# Epoch 25/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0430 - mae: 0.1433 - root_mean_squared_error: 0.2073
# Epoch 25: val_loss did not improve from 0.02767
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0457 - mae: 0.1450 - root_mean_squared_error: 0.2137 - val_loss: 0.0318 - val_mae: 0.1245 - val_root_mean_squared_error: 0.1783 - lr: 0.0010
# Epoch 26/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0450 - mae: 0.1421 - root_mean_squared_error: 0.2122
# Epoch 26: val_loss did not improve from 0.02767
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0443 - mae: 0.1416 - root_mean_squared_error: 0.2104 - val_loss: 0.0375 - val_mae: 0.1277 - val_root_mean_squared_error: 0.1937 - lr: 0.0010
# Epoch 27/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0531 - mae: 0.1462 - root_mean_squared_error: 0.2305
# Epoch 27: val_loss did not improve from 0.02767
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0528 - mae: 0.1468 - root_mean_squared_error: 0.2297 - val_loss: 0.0349 - val_mae: 0.1337 - val_root_mean_squared_error: 0.1869 - lr: 0.0010
# Epoch 28/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0390 - mae: 0.1385 - root_mean_squared_error: 0.1975
# Epoch 28: val_loss did not improve from 0.02767
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0399 - mae: 0.1387 - root_mean_squared_error: 0.1997 - val_loss: 0.0439 - val_mae: 0.1374 - val_root_mean_squared_error: 0.2096 - lr: 0.0010
# Epoch 29/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0441 - mae: 0.1439 - root_mean_squared_error: 0.2100
# Epoch 29: val_loss did not improve from 0.02767
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0518 - mae: 0.1457 - root_mean_squared_error: 0.2276 - val_loss: 0.0420 - val_mae: 0.1358 - val_root_mean_squared_error: 0.2049 - lr: 0.0010
# Epoch 30/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0441 - mae: 0.1418 - root_mean_squared_error: 0.2099
# Epoch 30: val_loss did not improve from 0.02767
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0442 - mae: 0.1415 - root_mean_squared_error: 0.2103 - val_loss: 0.0324 - val_mae: 0.1242 - val_root_mean_squared_error: 0.1801 - lr: 0.0010
# Epoch 31/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0399 - mae: 0.1348 - root_mean_squared_error: 0.1997
# Epoch 31: val_loss did not improve from 0.02767
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0426 - mae: 0.1356 - root_mean_squared_error: 0.2063 - val_loss: 0.0391 - val_mae: 0.1311 - val_root_mean_squared_error: 0.1978 - lr: 0.0010
# Epoch 32/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0485 - mae: 0.1491 - root_mean_squared_error: 0.2203
# Epoch 32: val_loss improved from 0.02767 to 0.02749, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0498 - mae: 0.1508 - root_mean_squared_error: 0.2232 - val_loss: 0.0275 - val_mae: 0.1147 - val_root_mean_squared_error: 0.1658 - lr: 0.0010
# Epoch 33/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0432 - mae: 0.1437 - root_mean_squared_error: 0.2078
# Epoch 33: val_loss did not improve from 0.02749
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0432 - mae: 0.1437 - root_mean_squared_error: 0.2078 - val_loss: 0.0347 - val_mae: 0.1325 - val_root_mean_squared_error: 0.1864 - lr: 0.0010
# Epoch 34/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0462 - mae: 0.1445 - root_mean_squared_error: 0.2149
# Epoch 34: val_loss did not improve from 0.02749
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0462 - mae: 0.1445 - root_mean_squared_error: 0.2149 - val_loss: 0.0501 - val_mae: 0.1535 - val_root_mean_squared_error: 0.2238 - lr: 0.0010
# Epoch 35/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0604 - mae: 0.1577 - root_mean_squared_error: 0.2457
# Epoch 35: val_loss did not improve from 0.02749
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0613 - mae: 0.1582 - root_mean_squared_error: 0.2476 - val_loss: 0.0427 - val_mae: 0.1449 - val_root_mean_squared_error: 0.2065 - lr: 0.0010
# Epoch 36/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0507 - mae: 0.1505 - root_mean_squared_error: 0.2253
# Epoch 36: val_loss did not improve from 0.02749
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0522 - mae: 0.1509 - root_mean_squared_error: 0.2284 - val_loss: 0.0306 - val_mae: 0.1219 - val_root_mean_squared_error: 0.1749 - lr: 0.0010
# Epoch 37/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0383 - mae: 0.1353 - root_mean_squared_error: 0.1956
# Epoch 37: val_loss did not improve from 0.02749
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0384 - mae: 0.1349 - root_mean_squared_error: 0.1961 - val_loss: 0.0305 - val_mae: 0.1172 - val_root_mean_squared_error: 0.1745 - lr: 0.0010
# Epoch 38/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0387 - mae: 0.1345 - root_mean_squared_error: 0.1966
# Epoch 38: val_loss did not improve from 0.02749
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0403 - mae: 0.1353 - root_mean_squared_error: 0.2008 - val_loss: 0.0532 - val_mae: 0.1531 - val_root_mean_squared_error: 0.2307 - lr: 0.0010
# Epoch 39/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0415 - mae: 0.1398 - root_mean_squared_error: 0.2038
# Epoch 39: val_loss improved from 0.02749 to 0.02571, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0415 - mae: 0.1398 - root_mean_squared_error: 0.2038 - val_loss: 0.0257 - val_mae: 0.1160 - val_root_mean_squared_error: 0.1604 - lr: 0.0010
# Epoch 40/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0346 - mae: 0.1275 - root_mean_squared_error: 0.1860
# Epoch 40: val_loss improved from 0.02571 to 0.02470, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0346 - mae: 0.1275 - root_mean_squared_error: 0.1860 - val_loss: 0.0247 - val_mae: 0.1125 - val_root_mean_squared_error: 0.1572 - lr: 0.0010
# Epoch 41/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0457 - mae: 0.1352 - root_mean_squared_error: 0.2138
# Epoch 41: val_loss did not improve from 0.02470
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0480 - mae: 0.1375 - root_mean_squared_error: 0.2190 - val_loss: 0.0334 - val_mae: 0.1238 - val_root_mean_squared_error: 0.1827 - lr: 0.0010
# Epoch 42/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0383 - mae: 0.1302 - root_mean_squared_error: 0.1958
# Epoch 42: val_loss did not improve from 0.02470
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0383 - mae: 0.1302 - root_mean_squared_error: 0.1958 - val_loss: 0.0254 - val_mae: 0.1138 - val_root_mean_squared_error: 0.1594 - lr: 0.0010
# Epoch 43/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0322 - mae: 0.1235 - root_mean_squared_error: 0.1793
# Epoch 43: val_loss did not improve from 0.02470
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0339 - mae: 0.1248 - root_mean_squared_error: 0.1840 - val_loss: 0.0314 - val_mae: 0.1204 - val_root_mean_squared_error: 0.1773 - lr: 0.0010
# Epoch 44/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0351 - mae: 0.1247 - root_mean_squared_error: 0.1873
# Epoch 44: val_loss did not improve from 0.02470
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0396 - mae: 0.1276 - root_mean_squared_error: 0.1990 - val_loss: 0.0348 - val_mae: 0.1257 - val_root_mean_squared_error: 0.1865 - lr: 0.0010
# Epoch 45/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0315 - mae: 0.1214 - root_mean_squared_error: 0.1775
# Epoch 45: val_loss did not improve from 0.02470
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0311 - mae: 0.1211 - root_mean_squared_error: 0.1763 - val_loss: 0.0264 - val_mae: 0.1141 - val_root_mean_squared_error: 0.1625 - lr: 0.0010
# Epoch 46/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0322 - mae: 0.1225 - root_mean_squared_error: 0.1795
# Epoch 46: val_loss did not improve from 0.02470
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0331 - mae: 0.1240 - root_mean_squared_error: 0.1821 - val_loss: 0.0653 - val_mae: 0.1761 - val_root_mean_squared_error: 0.2556 - lr: 0.0010
# Epoch 47/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0415 - mae: 0.1362 - root_mean_squared_error: 0.2038
# Epoch 47: val_loss did not improve from 0.02470
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0415 - mae: 0.1362 - root_mean_squared_error: 0.2038 - val_loss: 0.0324 - val_mae: 0.1222 - val_root_mean_squared_error: 0.1801 - lr: 0.0010
# Epoch 48/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0400 - mae: 0.1299 - root_mean_squared_error: 0.2001
# Epoch 48: val_loss did not improve from 0.02470
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0426 - mae: 0.1319 - root_mean_squared_error: 0.2064 - val_loss: 0.0259 - val_mae: 0.1144 - val_root_mean_squared_error: 0.1609 - lr: 0.0010
# Epoch 49/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0390 - mae: 0.1285 - root_mean_squared_error: 0.1974
# Epoch 49: val_loss did not improve from 0.02470
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0390 - mae: 0.1285 - root_mean_squared_error: 0.1974 - val_loss: 0.0359 - val_mae: 0.1261 - val_root_mean_squared_error: 0.1895 - lr: 0.0010
# Epoch 50/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0451 - mae: 0.1399 - root_mean_squared_error: 0.2123
# Epoch 50: val_loss did not improve from 0.02470
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0438 - mae: 0.1385 - root_mean_squared_error: 0.2094 - val_loss: 0.0294 - val_mae: 0.1215 - val_root_mean_squared_error: 0.1714 - lr: 0.0010
# Epoch 51/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0345 - mae: 0.1232 - root_mean_squared_error: 0.1858
# Epoch 51: val_loss did not improve from 0.02470
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0369 - mae: 0.1258 - root_mean_squared_error: 0.1922 - val_loss: 0.0255 - val_mae: 0.1142 - val_root_mean_squared_error: 0.1597 - lr: 0.0010
# Epoch 52/200
# 43/44 [============================>.] - ETA: 0s - loss: 0.0381 - mae: 0.1270 - root_mean_squared_error: 0.1952
# Epoch 52: val_loss did not improve from 0.02470
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0376 - mae: 0.1263 - root_mean_squared_error: 0.1940 - val_loss: 0.0315 - val_mae: 0.1198 - val_root_mean_squared_error: 0.1776 - lr: 0.0010
# Epoch 53/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0353 - mae: 0.1228 - root_mean_squared_error: 0.1878
# Epoch 53: val_loss did not improve from 0.02470
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0353 - mae: 0.1228 - root_mean_squared_error: 0.1878 - val_loss: 0.0272 - val_mae: 0.1154 - val_root_mean_squared_error: 0.1650 - lr: 0.0010
# Epoch 54/200
# 43/44 [============================>.] - ETA: 0s - loss: 0.0349 - mae: 0.1228 - root_mean_squared_error: 0.1868
# Epoch 54: val_loss did not improve from 0.02470
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0347 - mae: 0.1228 - root_mean_squared_error: 0.1863 - val_loss: 0.0307 - val_mae: 0.1255 - val_root_mean_squared_error: 0.1753 - lr: 0.0010
# Epoch 55/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0296 - mae: 0.1197 - root_mean_squared_error: 0.1721
# Epoch 55: val_loss did not improve from 0.02470
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0306 - mae: 0.1211 - root_mean_squared_error: 0.1751 - val_loss: 0.0346 - val_mae: 0.1368 - val_root_mean_squared_error: 0.1860 - lr: 0.0010
# Epoch 56/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0369 - mae: 0.1219 - root_mean_squared_error: 0.1920
# Epoch 56: val_loss did not improve from 0.02470
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0359 - mae: 0.1202 - root_mean_squared_error: 0.1894 - val_loss: 0.0251 - val_mae: 0.1151 - val_root_mean_squared_error: 0.1585 - lr: 5.0000e-04
# Epoch 57/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0293 - mae: 0.1128 - root_mean_squared_error: 0.1712
# Epoch 57: val_loss improved from 0.02470 to 0.02465, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0292 - mae: 0.1129 - root_mean_squared_error: 0.1710 - val_loss: 0.0247 - val_mae: 0.1104 - val_root_mean_squared_error: 0.1570 - lr: 5.0000e-04
# Epoch 58/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0293 - mae: 0.1104 - root_mean_squared_error: 0.1712
# Epoch 58: val_loss improved from 0.02465 to 0.02352, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0295 - mae: 0.1113 - root_mean_squared_error: 0.1719 - val_loss: 0.0235 - val_mae: 0.1119 - val_root_mean_squared_error: 0.1534 - lr: 5.0000e-04
# Epoch 59/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0264 - mae: 0.1110 - root_mean_squared_error: 0.1625
# Epoch 59: val_loss did not improve from 0.02352
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0267 - mae: 0.1114 - root_mean_squared_error: 0.1634 - val_loss: 0.0238 - val_mae: 0.1091 - val_root_mean_squared_error: 0.1543 - lr: 5.0000e-04
# Epoch 60/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0319 - mae: 0.1185 - root_mean_squared_error: 0.1786
# Epoch 60: val_loss improved from 0.02352 to 0.02347, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0350 - mae: 0.1200 - root_mean_squared_error: 0.1870 - val_loss: 0.0235 - val_mae: 0.1117 - val_root_mean_squared_error: 0.1532 - lr: 5.0000e-04
# Epoch 61/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0342 - mae: 0.1205 - root_mean_squared_error: 0.1849
# Epoch 61: val_loss did not improve from 0.02347
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0345 - mae: 0.1208 - root_mean_squared_error: 0.1858 - val_loss: 0.0262 - val_mae: 0.1162 - val_root_mean_squared_error: 0.1620 - lr: 5.0000e-04
# Epoch 62/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0335 - mae: 0.1141 - root_mean_squared_error: 0.1830
# Epoch 62: val_loss did not improve from 0.02347
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0344 - mae: 0.1155 - root_mean_squared_error: 0.1854 - val_loss: 0.0275 - val_mae: 0.1115 - val_root_mean_squared_error: 0.1659 - lr: 5.0000e-04
# Epoch 63/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0289 - mae: 0.1126 - root_mean_squared_error: 0.1699
# Epoch 63: val_loss improved from 0.02347 to 0.02162, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0306 - mae: 0.1155 - root_mean_squared_error: 0.1749 - val_loss: 0.0216 - val_mae: 0.1075 - val_root_mean_squared_error: 0.1470 - lr: 5.0000e-04
# Epoch 64/200
# 43/44 [============================>.] - ETA: 0s - loss: 0.0318 - mae: 0.1144 - root_mean_squared_error: 0.1784
# Epoch 64: val_loss did not improve from 0.02162
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0320 - mae: 0.1150 - root_mean_squared_error: 0.1790 - val_loss: 0.0311 - val_mae: 0.1226 - val_root_mean_squared_error: 0.1764 - lr: 5.0000e-04
# Epoch 65/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0310 - mae: 0.1165 - root_mean_squared_error: 0.1761
# Epoch 65: val_loss improved from 0.02162 to 0.02074, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0318 - mae: 0.1171 - root_mean_squared_error: 0.1784 - val_loss: 0.0207 - val_mae: 0.1034 - val_root_mean_squared_error: 0.1440 - lr: 5.0000e-04
# Epoch 66/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0284 - mae: 0.1122 - root_mean_squared_error: 0.1684
# Epoch 66: val_loss did not improve from 0.02074
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0290 - mae: 0.1119 - root_mean_squared_error: 0.1704 - val_loss: 0.0230 - val_mae: 0.1109 - val_root_mean_squared_error: 0.1518 - lr: 5.0000e-04
# Epoch 67/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0323 - mae: 0.1161 - root_mean_squared_error: 0.1797
# Epoch 67: val_loss did not improve from 0.02074
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0320 - mae: 0.1166 - root_mean_squared_error: 0.1790 - val_loss: 0.0238 - val_mae: 0.1108 - val_root_mean_squared_error: 0.1542 - lr: 5.0000e-04
# Epoch 68/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0248 - mae: 0.1059 - root_mean_squared_error: 0.1574
# Epoch 68: val_loss did not improve from 0.02074
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0359 - mae: 0.1084 - root_mean_squared_error: 0.1895 - val_loss: 0.0247 - val_mae: 0.1103 - val_root_mean_squared_error: 0.1570 - lr: 5.0000e-04
# Epoch 69/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0253 - mae: 0.1058 - root_mean_squared_error: 0.1591
# Epoch 69: val_loss improved from 0.02074 to 0.02054, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0265 - mae: 0.1076 - root_mean_squared_error: 0.1628 - val_loss: 0.0205 - val_mae: 0.1038 - val_root_mean_squared_error: 0.1433 - lr: 5.0000e-04
# Epoch 70/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0286 - mae: 0.1119 - root_mean_squared_error: 0.1692
# Epoch 70: val_loss did not improve from 0.02054
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0308 - mae: 0.1136 - root_mean_squared_error: 0.1755 - val_loss: 0.0229 - val_mae: 0.1075 - val_root_mean_squared_error: 0.1513 - lr: 5.0000e-04
# Epoch 71/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0259 - mae: 0.1070 - root_mean_squared_error: 0.1610
# Epoch 71: val_loss did not improve from 0.02054
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0265 - mae: 0.1079 - root_mean_squared_error: 0.1628 - val_loss: 0.0212 - val_mae: 0.1045 - val_root_mean_squared_error: 0.1454 - lr: 5.0000e-04
# Epoch 72/200
# 43/44 [============================>.] - ETA: 0s - loss: 0.0322 - mae: 0.1096 - root_mean_squared_error: 0.1795
# Epoch 72: val_loss did not improve from 0.02054
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0319 - mae: 0.1092 - root_mean_squared_error: 0.1786 - val_loss: 0.0226 - val_mae: 0.1094 - val_root_mean_squared_error: 0.1502 - lr: 5.0000e-04
# Epoch 73/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0245 - mae: 0.1048 - root_mean_squared_error: 0.1565
# Epoch 73: val_loss did not improve from 0.02054
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0265 - mae: 0.1057 - root_mean_squared_error: 0.1628 - val_loss: 0.0217 - val_mae: 0.1096 - val_root_mean_squared_error: 0.1474 - lr: 5.0000e-04
# Epoch 74/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0288 - mae: 0.1083 - root_mean_squared_error: 0.1696
# Epoch 74: val_loss did not improve from 0.02054
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0304 - mae: 0.1107 - root_mean_squared_error: 0.1743 - val_loss: 0.0256 - val_mae: 0.1179 - val_root_mean_squared_error: 0.1599 - lr: 5.0000e-04
# Epoch 75/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0242 - mae: 0.1053 - root_mean_squared_error: 0.1557
# Epoch 75: val_loss improved from 0.02054 to 0.02053, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0242 - mae: 0.1053 - root_mean_squared_error: 0.1557 - val_loss: 0.0205 - val_mae: 0.1060 - val_root_mean_squared_error: 0.1433 - lr: 5.0000e-04
# Epoch 76/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0282 - mae: 0.1092 - root_mean_squared_error: 0.1679
# Epoch 76: val_loss did not improve from 0.02053
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0282 - mae: 0.1092 - root_mean_squared_error: 0.1679 - val_loss: 0.0237 - val_mae: 0.1126 - val_root_mean_squared_error: 0.1540 - lr: 5.0000e-04
# Epoch 77/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0321 - mae: 0.1181 - root_mean_squared_error: 0.1791
# Epoch 77: val_loss did not improve from 0.02053
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0355 - mae: 0.1193 - root_mean_squared_error: 0.1884 - val_loss: 0.0414 - val_mae: 0.1363 - val_root_mean_squared_error: 0.2035 - lr: 5.0000e-04
# Epoch 78/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0261 - mae: 0.1070 - root_mean_squared_error: 0.1616
# Epoch 78: val_loss did not improve from 0.02053
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0257 - mae: 0.1064 - root_mean_squared_error: 0.1602 - val_loss: 0.0233 - val_mae: 0.1104 - val_root_mean_squared_error: 0.1528 - lr: 5.0000e-04
# Epoch 79/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0245 - mae: 0.1058 - root_mean_squared_error: 0.1566
# Epoch 79: val_loss did not improve from 0.02053
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0315 - mae: 0.1082 - root_mean_squared_error: 0.1774 - val_loss: 0.0367 - val_mae: 0.1281 - val_root_mean_squared_error: 0.1915 - lr: 5.0000e-04
# Epoch 80/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0340 - mae: 0.1153 - root_mean_squared_error: 0.1843
# Epoch 80: val_loss did not improve from 0.02053
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0334 - mae: 0.1149 - root_mean_squared_error: 0.1827 - val_loss: 0.0237 - val_mae: 0.1121 - val_root_mean_squared_error: 0.1541 - lr: 5.0000e-04
# Epoch 81/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0253 - mae: 0.1044 - root_mean_squared_error: 0.1592
# Epoch 81: val_loss did not improve from 0.02053
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0259 - mae: 0.1050 - root_mean_squared_error: 0.1608 - val_loss: 0.0319 - val_mae: 0.1213 - val_root_mean_squared_error: 0.1786 - lr: 5.0000e-04
# Epoch 82/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0337 - mae: 0.1123 - root_mean_squared_error: 0.1835
# Epoch 82: val_loss improved from 0.02053 to 0.02030, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0345 - mae: 0.1114 - root_mean_squared_error: 0.1857 - val_loss: 0.0203 - val_mae: 0.1039 - val_root_mean_squared_error: 0.1425 - lr: 5.0000e-04
# Epoch 83/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0255 - mae: 0.1065 - root_mean_squared_error: 0.1596
# Epoch 83: val_loss did not improve from 0.02030
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0253 - mae: 0.1063 - root_mean_squared_error: 0.1591 - val_loss: 0.0233 - val_mae: 0.1113 - val_root_mean_squared_error: 0.1527 - lr: 5.0000e-04
# Epoch 84/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0206 - mae: 0.0980 - root_mean_squared_error: 0.1436
# Epoch 84: val_loss did not improve from 0.02030
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0215 - mae: 0.0993 - root_mean_squared_error: 0.1466 - val_loss: 0.0246 - val_mae: 0.1115 - val_root_mean_squared_error: 0.1568 - lr: 5.0000e-04
# Epoch 85/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0239 - mae: 0.1012 - root_mean_squared_error: 0.1545
# Epoch 85: val_loss did not improve from 0.02030
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0248 - mae: 0.1012 - root_mean_squared_error: 0.1576 - val_loss: 0.0264 - val_mae: 0.1114 - val_root_mean_squared_error: 0.1625 - lr: 5.0000e-04
# Epoch 86/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0258 - mae: 0.1068 - root_mean_squared_error: 0.1607
# Epoch 86: val_loss did not improve from 0.02030
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0267 - mae: 0.1091 - root_mean_squared_error: 0.1635 - val_loss: 0.0292 - val_mae: 0.1259 - val_root_mean_squared_error: 0.1708 - lr: 5.0000e-04
# Epoch 87/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0273 - mae: 0.1093 - root_mean_squared_error: 0.1651
# Epoch 87: val_loss improved from 0.02030 to 0.02013, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0267 - mae: 0.1082 - root_mean_squared_error: 0.1634 - val_loss: 0.0201 - val_mae: 0.1035 - val_root_mean_squared_error: 0.1419 - lr: 5.0000e-04
# Epoch 88/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0272 - mae: 0.1068 - root_mean_squared_error: 0.1650
# Epoch 88: val_loss did not improve from 0.02013
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0318 - mae: 0.1088 - root_mean_squared_error: 0.1784 - val_loss: 0.0391 - val_mae: 0.1399 - val_root_mean_squared_error: 0.1977 - lr: 5.0000e-04
# Epoch 89/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0239 - mae: 0.1017 - root_mean_squared_error: 0.1546
# Epoch 89: val_loss did not improve from 0.02013
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0241 - mae: 0.1025 - root_mean_squared_error: 0.1551 - val_loss: 0.0311 - val_mae: 0.1276 - val_root_mean_squared_error: 0.1762 - lr: 5.0000e-04
# Epoch 90/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0254 - mae: 0.1015 - root_mean_squared_error: 0.1593
# Epoch 90: val_loss did not improve from 0.02013
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0248 - mae: 0.1013 - root_mean_squared_error: 0.1575 - val_loss: 0.0236 - val_mae: 0.1112 - val_root_mean_squared_error: 0.1538 - lr: 5.0000e-04
# Epoch 91/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0224 - mae: 0.1014 - root_mean_squared_error: 0.1495
# Epoch 91: val_loss did not improve from 0.02013
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0231 - mae: 0.1026 - root_mean_squared_error: 0.1519 - val_loss: 0.0329 - val_mae: 0.1319 - val_root_mean_squared_error: 0.1815 - lr: 5.0000e-04
# Epoch 92/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0231 - mae: 0.1025 - root_mean_squared_error: 0.1521
# Epoch 92: val_loss did not improve from 0.02013
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0228 - mae: 0.1019 - root_mean_squared_error: 0.1510 - val_loss: 0.0246 - val_mae: 0.1118 - val_root_mean_squared_error: 0.1570 - lr: 5.0000e-04
# Epoch 93/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0301 - mae: 0.1064 - root_mean_squared_error: 0.1734
# Epoch 93: val_loss did not improve from 0.02013
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0296 - mae: 0.1069 - root_mean_squared_error: 0.1721 - val_loss: 0.0344 - val_mae: 0.1360 - val_root_mean_squared_error: 0.1855 - lr: 5.0000e-04
# Epoch 94/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0234 - mae: 0.1046 - root_mean_squared_error: 0.1528
# Epoch 94: val_loss did not improve from 0.02013
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0259 - mae: 0.1062 - root_mean_squared_error: 0.1611 - val_loss: 0.0273 - val_mae: 0.1224 - val_root_mean_squared_error: 0.1652 - lr: 5.0000e-04
# Epoch 95/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0210 - mae: 0.0972 - root_mean_squared_error: 0.1450
# Epoch 95: val_loss did not improve from 0.02013
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0233 - mae: 0.0983 - root_mean_squared_error: 0.1526 - val_loss: 0.0245 - val_mae: 0.1127 - val_root_mean_squared_error: 0.1567 - lr: 5.0000e-04
# Epoch 96/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0247 - mae: 0.1034 - root_mean_squared_error: 0.1572
# Epoch 96: val_loss did not improve from 0.02013
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0247 - mae: 0.1034 - root_mean_squared_error: 0.1572 - val_loss: 0.0384 - val_mae: 0.1424 - val_root_mean_squared_error: 0.1960 - lr: 5.0000e-04
# Epoch 97/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0214 - mae: 0.1025 - root_mean_squared_error: 0.1463
# Epoch 97: val_loss did not improve from 0.02013
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0214 - mae: 0.1025 - root_mean_squared_error: 0.1463 - val_loss: 0.0283 - val_mae: 0.1207 - val_root_mean_squared_error: 0.1682 - lr: 5.0000e-04
# Epoch 98/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0254 - mae: 0.1040 - root_mean_squared_error: 0.1595
# Epoch 98: val_loss did not improve from 0.02013
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0254 - mae: 0.1040 - root_mean_squared_error: 0.1595 - val_loss: 0.0280 - val_mae: 0.1213 - val_root_mean_squared_error: 0.1672 - lr: 5.0000e-04
# Epoch 99/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0218 - mae: 0.0961 - root_mean_squared_error: 0.1477
# Epoch 99: val_loss did not improve from 0.02013
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0236 - mae: 0.0979 - root_mean_squared_error: 0.1537 - val_loss: 0.0247 - val_mae: 0.1129 - val_root_mean_squared_error: 0.1572 - lr: 5.0000e-04
# Epoch 100/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0241 - mae: 0.1028 - root_mean_squared_error: 0.1552
# Epoch 100: val_loss did not improve from 0.02013
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0241 - mae: 0.1028 - root_mean_squared_error: 0.1552 - val_loss: 0.0268 - val_mae: 0.1190 - val_root_mean_squared_error: 0.1638 - lr: 5.0000e-04
# Epoch 101/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0204 - mae: 0.0996 - root_mean_squared_error: 0.1429
# Epoch 101: val_loss did not improve from 0.02013
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0201 - mae: 0.0992 - root_mean_squared_error: 0.1418 - val_loss: 0.0242 - val_mae: 0.1106 - val_root_mean_squared_error: 0.1557 - lr: 5.0000e-04
# Epoch 102/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0257 - mae: 0.0977 - root_mean_squared_error: 0.1603
# Epoch 102: val_loss did not improve from 0.02013
#
# Epoch 102: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0257 - mae: 0.0977 - root_mean_squared_error: 0.1603 - val_loss: 0.0237 - val_mae: 0.1137 - val_root_mean_squared_error: 0.1539 - lr: 5.0000e-04
# Epoch 103/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0212 - mae: 0.0935 - root_mean_squared_error: 0.1458
# Epoch 103: val_loss did not improve from 0.02013
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0210 - mae: 0.0934 - root_mean_squared_error: 0.1451 - val_loss: 0.0211 - val_mae: 0.1082 - val_root_mean_squared_error: 0.1453 - lr: 2.5000e-04
# Epoch 104/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0275 - mae: 0.1052 - root_mean_squared_error: 0.1660
# Epoch 104: val_loss did not improve from 0.02013
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0279 - mae: 0.1054 - root_mean_squared_error: 0.1670 - val_loss: 0.0239 - val_mae: 0.1119 - val_root_mean_squared_error: 0.1547 - lr: 2.5000e-04
# Epoch 105/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0206 - mae: 0.0938 - root_mean_squared_error: 0.1435
# Epoch 105: val_loss improved from 0.02013 to 0.01974, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0240 - mae: 0.0953 - root_mean_squared_error: 0.1549 - val_loss: 0.0197 - val_mae: 0.1048 - val_root_mean_squared_error: 0.1405 - lr: 2.5000e-04
# Epoch 106/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0198 - mae: 0.0946 - root_mean_squared_error: 0.1407
# Epoch 106: val_loss did not improve from 0.01974
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0219 - mae: 0.0965 - root_mean_squared_error: 0.1481 - val_loss: 0.0203 - val_mae: 0.1046 - val_root_mean_squared_error: 0.1424 - lr: 2.5000e-04
# Epoch 107/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0221 - mae: 0.0940 - root_mean_squared_error: 0.1488
# Epoch 107: val_loss did not improve from 0.01974
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0221 - mae: 0.0942 - root_mean_squared_error: 0.1488 - val_loss: 0.0223 - val_mae: 0.1104 - val_root_mean_squared_error: 0.1493 - lr: 2.5000e-04
# Epoch 108/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0236 - mae: 0.0989 - root_mean_squared_error: 0.1537
# Epoch 108: val_loss did not improve from 0.01974
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0237 - mae: 0.0990 - root_mean_squared_error: 0.1539 - val_loss: 0.0236 - val_mae: 0.1111 - val_root_mean_squared_error: 0.1536 - lr: 2.5000e-04
# Epoch 109/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0183 - mae: 0.0883 - root_mean_squared_error: 0.1354
# Epoch 109: val_loss did not improve from 0.01974
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0187 - mae: 0.0888 - root_mean_squared_error: 0.1366 - val_loss: 0.0220 - val_mae: 0.1096 - val_root_mean_squared_error: 0.1485 - lr: 2.5000e-04
# Epoch 110/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0205 - mae: 0.0949 - root_mean_squared_error: 0.1433
# Epoch 110: val_loss did not improve from 0.01974
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0214 - mae: 0.0948 - root_mean_squared_error: 0.1462 - val_loss: 0.0201 - val_mae: 0.1054 - val_root_mean_squared_error: 0.1417 - lr: 2.5000e-04
# Epoch 111/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0199 - mae: 0.0919 - root_mean_squared_error: 0.1410
# Epoch 111: val_loss did not improve from 0.01974
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0194 - mae: 0.0910 - root_mean_squared_error: 0.1394 - val_loss: 0.0199 - val_mae: 0.1061 - val_root_mean_squared_error: 0.1412 - lr: 2.5000e-04
# Epoch 112/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0202 - mae: 0.0912 - root_mean_squared_error: 0.1420
# Epoch 112: val_loss did not improve from 0.01974
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0202 - mae: 0.0912 - root_mean_squared_error: 0.1420 - val_loss: 0.0227 - val_mae: 0.1101 - val_root_mean_squared_error: 0.1508 - lr: 2.5000e-04
# Epoch 113/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0216 - mae: 0.0930 - root_mean_squared_error: 0.1471
# Epoch 113: val_loss did not improve from 0.01974
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0216 - mae: 0.0930 - root_mean_squared_error: 0.1471 - val_loss: 0.0231 - val_mae: 0.1082 - val_root_mean_squared_error: 0.1519 - lr: 2.5000e-04
# Epoch 114/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0224 - mae: 0.0939 - root_mean_squared_error: 0.1497
# Epoch 114: val_loss did not improve from 0.01974
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0230 - mae: 0.0953 - root_mean_squared_error: 0.1515 - val_loss: 0.0343 - val_mae: 0.1290 - val_root_mean_squared_error: 0.1852 - lr: 2.5000e-04
# Epoch 115/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0181 - mae: 0.0907 - root_mean_squared_error: 0.1346
# Epoch 115: val_loss did not improve from 0.01974
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0192 - mae: 0.0919 - root_mean_squared_error: 0.1384 - val_loss: 0.0207 - val_mae: 0.1042 - val_root_mean_squared_error: 0.1437 - lr: 2.5000e-04
# Epoch 116/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0234 - mae: 0.0971 - root_mean_squared_error: 0.1530
# Epoch 116: val_loss did not improve from 0.01974
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0259 - mae: 0.0981 - root_mean_squared_error: 0.1609 - val_loss: 0.0320 - val_mae: 0.1225 - val_root_mean_squared_error: 0.1788 - lr: 2.5000e-04
# Epoch 117/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0241 - mae: 0.0950 - root_mean_squared_error: 0.1551
# Epoch 117: val_loss did not improve from 0.01974
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0263 - mae: 0.0957 - root_mean_squared_error: 0.1622 - val_loss: 0.0215 - val_mae: 0.1092 - val_root_mean_squared_error: 0.1468 - lr: 2.5000e-04
# Epoch 118/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0175 - mae: 0.0910 - root_mean_squared_error: 0.1324
# Epoch 118: val_loss did not improve from 0.01974
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0204 - mae: 0.0921 - root_mean_squared_error: 0.1427 - val_loss: 0.0216 - val_mae: 0.1094 - val_root_mean_squared_error: 0.1471 - lr: 2.5000e-04
# Epoch 119/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0207 - mae: 0.0924 - root_mean_squared_error: 0.1439
# Epoch 119: val_loss did not improve from 0.01974
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0209 - mae: 0.0931 - root_mean_squared_error: 0.1447 - val_loss: 0.0285 - val_mae: 0.1188 - val_root_mean_squared_error: 0.1689 - lr: 2.5000e-04
# Epoch 120/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0235 - mae: 0.0930 - root_mean_squared_error: 0.1534
# Epoch 120: val_loss did not improve from 0.01974
#
# Epoch 120: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# ...
# Epoch 160: val_loss did not improve from 0.01882
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0195 - mae: 0.0859 - root_mean_squared_error: 0.1397 - val_loss: 0.0192 - val_mae: 0.1039 - val_root_mean_squared_error: 0.1385 - lr: 6.2500e-05
# Epoch 161/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0163 - mae: 0.0834 - root_mean_squared_error: 0.1278
# Epoch 161: val_loss did not improve from 0.01882
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0169 - mae: 0.0838 - root_mean_squared_error: 0.1299 - val_loss: 0.0204 - val_mae: 0.1053 - val_root_mean_squared_error: 0.1429 - lr: 6.2500e-05
# Epoch 162/200
# 43/44 [============================>.] - ETA: 0s - loss: 0.0201 - mae: 0.0860 - root_mean_squared_error: 0.1419
# Epoch 162: val_loss did not improve from 0.01882
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0202 - mae: 0.0861 - root_mean_squared_error: 0.1420 - val_loss: 0.0189 - val_mae: 0.1023 - val_root_mean_squared_error: 0.1375 - lr: 6.2500e-05
# Epoch 163/200
# 43/44 [============================>.] - ETA: 0s - loss: 0.0195 - mae: 0.0875 - root_mean_squared_error: 0.1397
# Epoch 163: val_loss did not improve from 0.01882
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0193 - mae: 0.0871 - root_mean_squared_error: 0.1389 - val_loss: 0.0207 - val_mae: 0.1060 - val_root_mean_squared_error: 0.1438 - lr: 6.2500e-05
# Epoch 164/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0189 - mae: 0.0887 - root_mean_squared_error: 0.1373
# Epoch 164: val_loss did not improve from 0.01882
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0189 - mae: 0.0887 - root_mean_squared_error: 0.1373 - val_loss: 0.0199 - val_mae: 0.1053 - val_root_mean_squared_error: 0.1409 - lr: 6.2500e-05
# Epoch 165/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0227 - mae: 0.0930 - root_mean_squared_error: 0.1506
# Epoch 165: val_loss did not improve from 0.01882
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0227 - mae: 0.0930 - root_mean_squared_error: 0.1506 - val_loss: 0.0198 - val_mae: 0.1045 - val_root_mean_squared_error: 0.1407 - lr: 6.2500e-05
# Epoch 166/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0207 - mae: 0.0874 - root_mean_squared_error: 0.1440
# Epoch 166: val_loss did not improve from 0.01882
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0202 - mae: 0.0869 - root_mean_squared_error: 0.1421 - val_loss: 0.0192 - val_mae: 0.1030 - val_root_mean_squared_error: 0.1387 - lr: 6.2500e-05
# Epoch 167/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0200 - mae: 0.0851 - root_mean_squared_error: 0.1413
# Epoch 167: val_loss did not improve from 0.01882
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0200 - mae: 0.0851 - root_mean_squared_error: 0.1413 - val_loss: 0.0202 - val_mae: 0.1047 - val_root_mean_squared_error: 0.1422 - lr: 6.2500e-05
# Epoch 168/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0171 - mae: 0.0836 - root_mean_squared_error: 0.1307
# Epoch 168: val_loss did not improve from 0.01882
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0166 - mae: 0.0828 - root_mean_squared_error: 0.1288 - val_loss: 0.0189 - val_mae: 0.1034 - val_root_mean_squared_error: 0.1376 - lr: 6.2500e-05
# Epoch 169/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0156 - mae: 0.0824 - root_mean_squared_error: 0.1248
# Epoch 169: val_loss did not improve from 0.01882
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0171 - mae: 0.0837 - root_mean_squared_error: 0.1309 - val_loss: 0.0198 - val_mae: 0.1047 - val_root_mean_squared_error: 0.1406 - lr: 6.2500e-05
# Epoch 170/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0209 - mae: 0.0899 - root_mean_squared_error: 0.1446
# Epoch 170: val_loss did not improve from 0.01882
#
# Epoch 170: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0209 - mae: 0.0899 - root_mean_squared_error: 0.1446 - val_loss: 0.0197 - val_mae: 0.1048 - val_root_mean_squared_error: 0.1403 - lr: 6.2500e-05
# Epoch 171/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0193 - mae: 0.0875 - root_mean_squared_error: 0.1388
# Epoch 171: val_loss did not improve from 0.01882
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0196 - mae: 0.0881 - root_mean_squared_error: 0.1400 - val_loss: 0.0198 - val_mae: 0.1047 - val_root_mean_squared_error: 0.1408 - lr: 3.1250e-05
# Epoch 172/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0206 - mae: 0.0875 - root_mean_squared_error: 0.1435
# Epoch 172: val_loss did not improve from 0.01882
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0225 - mae: 0.0883 - root_mean_squared_error: 0.1499 - val_loss: 0.0197 - val_mae: 0.1048 - val_root_mean_squared_error: 0.1402 - lr: 3.1250e-05
# Epoch 173/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0166 - mae: 0.0826 - root_mean_squared_error: 0.1288
# Epoch 173: val_loss did not improve from 0.01882
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0163 - mae: 0.0817 - root_mean_squared_error: 0.1278 - val_loss: 0.0199 - val_mae: 0.1052 - val_root_mean_squared_error: 0.1411 - lr: 3.1250e-05
# Epoch 174/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0157 - mae: 0.0822 - root_mean_squared_error: 0.1253
# Epoch 174: val_loss did not improve from 0.01882
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0159 - mae: 0.0826 - root_mean_squared_error: 0.1263 - val_loss: 0.0194 - val_mae: 0.1042 - val_root_mean_squared_error: 0.1391 - lr: 3.1250e-05
# Epoch 175/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0168 - mae: 0.0832 - root_mean_squared_error: 0.1295
# Epoch 175: val_loss did not improve from 0.01882
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0168 - mae: 0.0832 - root_mean_squared_error: 0.1295 - val_loss: 0.0189 - val_mae: 0.1033 - val_root_mean_squared_error: 0.1374 - lr: 3.1250e-05
# Epoch 176/200
# 43/44 [============================>.] - ETA: 0s - loss: 0.0196 - mae: 0.0874 - root_mean_squared_error: 0.1400
# Epoch 176: val_loss improved from 0.01882 to 0.01873, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_lstm_model.h5
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0194 - mae: 0.0868 - root_mean_squared_error: 0.1391 - val_loss: 0.0187 - val_mae: 0.1031 - val_root_mean_squared_error: 0.1369 - lr: 3.1250e-05
# Epoch 177/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0143 - mae: 0.0815 - root_mean_squared_error: 0.1197
# Epoch 177: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0143 - mae: 0.0815 - root_mean_squared_error: 0.1197 - val_loss: 0.0188 - val_mae: 0.1037 - val_root_mean_squared_error: 0.1372 - lr: 3.1250e-05
# Epoch 178/200
# 43/44 [============================>.] - ETA: 0s - loss: 0.0173 - mae: 0.0838 - root_mean_squared_error: 0.1315
# Epoch 178: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0172 - mae: 0.0840 - root_mean_squared_error: 0.1312 - val_loss: 0.0189 - val_mae: 0.1031 - val_root_mean_squared_error: 0.1373 - lr: 3.1250e-05
# Epoch 179/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0164 - mae: 0.0832 - root_mean_squared_error: 0.1281
# Epoch 179: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0179 - mae: 0.0834 - root_mean_squared_error: 0.1337 - val_loss: 0.0195 - val_mae: 0.1048 - val_root_mean_squared_error: 0.1397 - lr: 3.1250e-05
# Epoch 180/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0206 - mae: 0.0865 - root_mean_squared_error: 0.1435
# Epoch 180: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0204 - mae: 0.0864 - root_mean_squared_error: 0.1428 - val_loss: 0.0190 - val_mae: 0.1035 - val_root_mean_squared_error: 0.1378 - lr: 3.1250e-05
# Epoch 181/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0224 - mae: 0.0895 - root_mean_squared_error: 0.1497
# Epoch 181: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0224 - mae: 0.0895 - root_mean_squared_error: 0.1497 - val_loss: 0.0194 - val_mae: 0.1039 - val_root_mean_squared_error: 0.1393 - lr: 3.1250e-05
# Epoch 182/200
# 43/44 [============================>.] - ETA: 0s - loss: 0.0196 - mae: 0.0872 - root_mean_squared_error: 0.1398
# Epoch 182: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0199 - mae: 0.0873 - root_mean_squared_error: 0.1410 - val_loss: 0.0199 - val_mae: 0.1053 - val_root_mean_squared_error: 0.1411 - lr: 3.1250e-05
# Epoch 183/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0177 - mae: 0.0846 - root_mean_squared_error: 0.1331
# Epoch 183: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0176 - mae: 0.0848 - root_mean_squared_error: 0.1328 - val_loss: 0.0196 - val_mae: 0.1043 - val_root_mean_squared_error: 0.1402 - lr: 3.1250e-05
# Epoch 184/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0190 - mae: 0.0870 - root_mean_squared_error: 0.1378
# Epoch 184: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0188 - mae: 0.0869 - root_mean_squared_error: 0.1370 - val_loss: 0.0199 - val_mae: 0.1048 - val_root_mean_squared_error: 0.1411 - lr: 3.1250e-05
# Epoch 185/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0197 - mae: 0.0832 - root_mean_squared_error: 0.1403
# Epoch 185: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0197 - mae: 0.0832 - root_mean_squared_error: 0.1403 - val_loss: 0.0192 - val_mae: 0.1033 - val_root_mean_squared_error: 0.1387 - lr: 3.1250e-05
# Epoch 186/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0155 - mae: 0.0820 - root_mean_squared_error: 0.1244
# Epoch 186: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0151 - mae: 0.0814 - root_mean_squared_error: 0.1229 - val_loss: 0.0192 - val_mae: 0.1041 - val_root_mean_squared_error: 0.1387 - lr: 3.1250e-05
# Epoch 187/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0167 - mae: 0.0827 - root_mean_squared_error: 0.1293
# Epoch 187: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0174 - mae: 0.0831 - root_mean_squared_error: 0.1321 - val_loss: 0.0200 - val_mae: 0.1044 - val_root_mean_squared_error: 0.1413 - lr: 3.1250e-05
# Epoch 188/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0189 - mae: 0.0833 - root_mean_squared_error: 0.1374
# Epoch 188: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0189 - mae: 0.0833 - root_mean_squared_error: 0.1374 - val_loss: 0.0196 - val_mae: 0.1032 - val_root_mean_squared_error: 0.1399 - lr: 3.1250e-05
# Epoch 189/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0190 - mae: 0.0848 - root_mean_squared_error: 0.1378
# Epoch 189: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0190 - mae: 0.0852 - root_mean_squared_error: 0.1380 - val_loss: 0.0195 - val_mae: 0.1035 - val_root_mean_squared_error: 0.1398 - lr: 3.1250e-05
# Epoch 190/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0162 - mae: 0.0836 - root_mean_squared_error: 0.1271
# Epoch 190: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0159 - mae: 0.0834 - root_mean_squared_error: 0.1263 - val_loss: 0.0193 - val_mae: 0.1031 - val_root_mean_squared_error: 0.1388 - lr: 3.1250e-05
# Epoch 191/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0186 - mae: 0.0864 - root_mean_squared_error: 0.1365
# Epoch 191: val_loss did not improve from 0.01873
#
# Epoch 191: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0185 - mae: 0.0864 - root_mean_squared_error: 0.1361 - val_loss: 0.0189 - val_mae: 0.1033 - val_root_mean_squared_error: 0.1373 - lr: 3.1250e-05
# Epoch 192/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0172 - mae: 0.0845 - root_mean_squared_error: 0.1311
# Epoch 192: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0172 - mae: 0.0845 - root_mean_squared_error: 0.1311 - val_loss: 0.0189 - val_mae: 0.1028 - val_root_mean_squared_error: 0.1373 - lr: 1.5625e-05
# Epoch 193/200
# 43/44 [============================>.] - ETA: 0s - loss: 0.0159 - mae: 0.0799 - root_mean_squared_error: 0.1260
# Epoch 193: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0158 - mae: 0.0798 - root_mean_squared_error: 0.1258 - val_loss: 0.0189 - val_mae: 0.1029 - val_root_mean_squared_error: 0.1375 - lr: 1.5625e-05
# Epoch 194/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0200 - mae: 0.0864 - root_mean_squared_error: 0.1415
# Epoch 194: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0205 - mae: 0.0864 - root_mean_squared_error: 0.1432 - val_loss: 0.0190 - val_mae: 0.1034 - val_root_mean_squared_error: 0.1380 - lr: 1.5625e-05
# Epoch 195/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0148 - mae: 0.0811 - root_mean_squared_error: 0.1216
# Epoch 195: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0152 - mae: 0.0810 - root_mean_squared_error: 0.1235 - val_loss: 0.0189 - val_mae: 0.1026 - val_root_mean_squared_error: 0.1374 - lr: 1.5625e-05
# Epoch 196/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0151 - mae: 0.0800 - root_mean_squared_error: 0.1228
# Epoch 196: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0151 - mae: 0.0800 - root_mean_squared_error: 0.1228 - val_loss: 0.0189 - val_mae: 0.1024 - val_root_mean_squared_error: 0.1374 - lr: 1.5625e-05
# Epoch 197/200
# 44/44 [==============================] - ETA: 0s - loss: 0.0164 - mae: 0.0842 - root_mean_squared_error: 0.1281
# Epoch 197: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0164 - mae: 0.0842 - root_mean_squared_error: 0.1281 - val_loss: 0.0190 - val_mae: 0.1030 - val_root_mean_squared_error: 0.1379 - lr: 1.5625e-05
# Epoch 198/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0206 - mae: 0.0883 - root_mean_squared_error: 0.1434
# Epoch 198: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0211 - mae: 0.0885 - root_mean_squared_error: 0.1451 - val_loss: 0.0194 - val_mae: 0.1038 - val_root_mean_squared_error: 0.1394 - lr: 1.5625e-05
# Epoch 199/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0159 - mae: 0.0820 - root_mean_squared_error: 0.1261
# Epoch 199: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0172 - mae: 0.0827 - root_mean_squared_error: 0.1311 - val_loss: 0.0193 - val_mae: 0.1038 - val_root_mean_squared_error: 0.1390 - lr: 1.5625e-05
# Epoch 200/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0157 - mae: 0.0808 - root_mean_squared_error: 0.1253
# Epoch 200: val_loss did not improve from 0.01873
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0160 - mae: 0.0809 - root_mean_squared_error: 0.1264 - val_loss: 0.0195 - val_mae: 0.1043 - val_root_mean_squared_error: 0.1398 - lr: 1.5625e-05
#
# ✓ LSTM訓練完成！

# %% [markdown]
# ### 5.3 訓練GRU模型

# %%
print("開始訓練GRU模型...\n")

# 編譯GRU模型
model_gru.compile(
    optimizer=Adam(learning_rate=0.001, clipnorm=1.0),
    loss='mse',
    metrics=['mae', 'RootMeanSquaredError']
)

# 訓練
history_gru = model_gru.fit(
    X_train_scaled, y_train_scaled,
    epochs=200,
    batch_size=32,
    validation_data=(X_val_scaled, y_val_scaled),
    callbacks=callbacks_gru,
    shuffle=False,
    verbose=1
)

print("\n✓ GRU訓練完成！")
# Out:
# 開始訓練GRU模型...
#
# Epoch 1/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.4037 - mae: 0.4377 - root_mean_squared_error: 0.6354
# Epoch 1: val_loss improved from inf to 0.10885, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_gru_model.h5
# 44/44 [==============================] - 4s 35ms/step - loss: 0.3994 - mae: 0.4305 - root_mean_squared_error: 0.6320 - val_loss: 0.1089 - val_mae: 0.2475 - val_root_mean_squared_error: 0.3299 - lr: 0.0010
# Epoch 2/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.1458 - mae: 0.2564 - root_mean_squared_error: 0.3818
# Epoch 2: val_loss improved from 0.10885 to 0.06846, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_gru_model.h5
# 44/44 [==============================] - 1s 17ms/step - loss: 0.1546 - mae: 0.2581 - root_mean_squared_error: 0.3932 - val_loss: 0.0685 - val_mae: 0.1953 - val_root_mean_squared_error: 0.2617 - lr: 0.0010
# Epoch 3/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.1227 - mae: 0.2341 - root_mean_squared_error: 0.3503
# Epoch 3: val_loss did not improve from 0.06846
# 44/44 [==============================] - 1s 15ms/step - loss: 0.1249 - mae: 0.2358 - root_mean_squared_error: 0.3534 - val_loss: 0.0716 - val_mae: 0.1950 - val_root_mean_squared_error: 0.2676 - lr: 0.0010
# Epoch 4/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.1089 - mae: 0.2293 - root_mean_squared_error: 0.3299
# Epoch 4: val_loss did not improve from 0.06846
# 44/44 [==============================] - 1s 16ms/step - loss: 0.1154 - mae: 0.2318 - root_mean_squared_error: 0.3397 - val_loss: 0.1197 - val_mae: 0.2584 - val_root_mean_squared_error: 0.3460 - lr: 0.0010
# Epoch 5/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.1131 - mae: 0.2263 - root_mean_squared_error: 0.3363
# Epoch 5: val_loss improved from 0.06846 to 0.04722, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_gru_model.h5
# 44/44 [==============================] - 1s 17ms/step - loss: 0.1158 - mae: 0.2270 - root_mean_squared_error: 0.3402 - val_loss: 0.0472 - val_mae: 0.1623 - val_root_mean_squared_error: 0.2173 - lr: 0.0010
# Epoch 6/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0946 - mae: 0.2108 - root_mean_squared_error: 0.3076
# Epoch 6: val_loss did not improve from 0.04722
# 44/44 [==============================] - 1s 16ms/step - loss: 0.1062 - mae: 0.2148 - root_mean_squared_error: 0.3259 - val_loss: 0.0616 - val_mae: 0.1830 - val_root_mean_squared_error: 0.2481 - lr: 0.0010
# Epoch 7/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0976 - mae: 0.2058 - root_mean_squared_error: 0.3124
# Epoch 7: val_loss did not improve from 0.04722
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0978 - mae: 0.2068 - root_mean_squared_error: 0.3127 - val_loss: 0.0762 - val_mae: 0.2025 - val_root_mean_squared_error: 0.2760 - lr: 0.0010
# Epoch 8/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0765 - mae: 0.1879 - root_mean_squared_error: 0.2765
# Epoch 8: val_loss did not improve from 0.04722
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0781 - mae: 0.1890 - root_mean_squared_error: 0.2795 - val_loss: 0.0518 - val_mae: 0.1653 - val_root_mean_squared_error: 0.2276 - lr: 0.0010
# Epoch 9/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0766 - mae: 0.1919 - root_mean_squared_error: 0.2768
# Epoch 9: val_loss did not improve from 0.04722
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0803 - mae: 0.1919 - root_mean_squared_error: 0.2833 - val_loss: 0.0550 - val_mae: 0.1725 - val_root_mean_squared_error: 0.2344 - lr: 0.0010
# Epoch 10/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0700 - mae: 0.1856 - root_mean_squared_error: 0.2646
# Epoch 10: val_loss improved from 0.04722 to 0.03702, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_gru_model.h5
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0734 - mae: 0.1848 - root_mean_squared_error: 0.2709 - val_loss: 0.0370 - val_mae: 0.1390 - val_root_mean_squared_error: 0.1924 - lr: 0.0010
# Epoch 11/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0584 - mae: 0.1722 - root_mean_squared_error: 0.2418
# Epoch 11: val_loss did not improve from 0.03702
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0623 - mae: 0.1745 - root_mean_squared_error: 0.2496 - val_loss: 0.0392 - val_mae: 0.1460 - val_root_mean_squared_error: 0.1980 - lr: 0.0010
# Epoch 12/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0710 - mae: 0.1789 - root_mean_squared_error: 0.2664
# Epoch 12: val_loss did not improve from 0.03702
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0703 - mae: 0.1791 - root_mean_squared_error: 0.2652 - val_loss: 0.0551 - val_mae: 0.1734 - val_root_mean_squared_error: 0.2348 - lr: 0.0010
# Epoch 13/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0583 - mae: 0.1671 - root_mean_squared_error: 0.2415
# Epoch 13: val_loss did not improve from 0.03702
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0609 - mae: 0.1696 - root_mean_squared_error: 0.2469 - val_loss: 0.0392 - val_mae: 0.1457 - val_root_mean_squared_error: 0.1979 - lr: 0.0010
# Epoch 14/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0621 - mae: 0.1725 - root_mean_squared_error: 0.2492
# Epoch 14: val_loss did not improve from 0.03702
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0741 - mae: 0.1749 - root_mean_squared_error: 0.2722 - val_loss: 0.0410 - val_mae: 0.1455 - val_root_mean_squared_error: 0.2025 - lr: 0.0010
# Epoch 15/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0541 - mae: 0.1643 - root_mean_squared_error: 0.2326
# Epoch 15: val_loss did not improve from 0.03702
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0545 - mae: 0.1629 - root_mean_squared_error: 0.2335 - val_loss: 0.0496 - val_mae: 0.1576 - val_root_mean_squared_error: 0.2226 - lr: 0.0010
# Epoch 16/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0497 - mae: 0.1570 - root_mean_squared_error: 0.2229
# Epoch 16: val_loss did not improve from 0.03702
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0495 - mae: 0.1571 - root_mean_squared_error: 0.2225 - val_loss: 0.0371 - val_mae: 0.1468 - val_root_mean_squared_error: 0.1926 - lr: 0.0010
# Epoch 17/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0597 - mae: 0.1677 - root_mean_squared_error: 0.2444
# Epoch 17: val_loss did not improve from 0.03702
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0606 - mae: 0.1686 - root_mean_squared_error: 0.2462 - val_loss: 0.0534 - val_mae: 0.1559 - val_root_mean_squared_error: 0.2311 - lr: 0.0010
# Epoch 18/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0564 - mae: 0.1666 - root_mean_squared_error: 0.2374
# Epoch 18: val_loss did not improve from 0.03702
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0569 - mae: 0.1668 - root_mean_squared_error: 0.2386 - val_loss: 0.0560 - val_mae: 0.1676 - val_root_mean_squared_error: 0.2367 - lr: 0.0010
# Epoch 19/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0465 - mae: 0.1536 - root_mean_squared_error: 0.2157
# Epoch 19: val_loss improved from 0.03702 to 0.03072, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_gru_model.h5
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0478 - mae: 0.1549 - root_mean_squared_error: 0.2186 - val_loss: 0.0307 - val_mae: 0.1285 - val_root_mean_squared_error: 0.1753 - lr: 0.0010
# Epoch 20/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0550 - mae: 0.1580 - root_mean_squared_error: 0.2345
# Epoch 20: val_loss did not improve from 0.03072
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0561 - mae: 0.1591 - root_mean_squared_error: 0.2369 - val_loss: 0.0506 - val_mae: 0.1506 - val_root_mean_squared_error: 0.2250 - lr: 0.0010
# Epoch 21/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0515 - mae: 0.1600 - root_mean_squared_error: 0.2270
# Epoch 21: val_loss did not improve from 0.03072
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0532 - mae: 0.1627 - root_mean_squared_error: 0.2307 - val_loss: 0.0642 - val_mae: 0.1967 - val_root_mean_squared_error: 0.2534 - lr: 0.0010
# Epoch 22/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0553 - mae: 0.1547 - root_mean_squared_error: 0.2353
# Epoch 22: val_loss did not improve from 0.03072
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0550 - mae: 0.1547 - root_mean_squared_error: 0.2345 - val_loss: 0.0327 - val_mae: 0.1261 - val_root_mean_squared_error: 0.1808 - lr: 0.0010
# Epoch 23/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0449 - mae: 0.1456 - root_mean_squared_error: 0.2118
# Epoch 23: val_loss did not improve from 0.03072
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0467 - mae: 0.1486 - root_mean_squared_error: 0.2161 - val_loss: 0.0641 - val_mae: 0.1957 - val_root_mean_squared_error: 0.2532 - lr: 0.0010
# Epoch 24/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0656 - mae: 0.1718 - root_mean_squared_error: 0.2562
# Epoch 24: val_loss improved from 0.03072 to 0.02852, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_gru_model.h5
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0638 - mae: 0.1699 - root_mean_squared_error: 0.2526 - val_loss: 0.0285 - val_mae: 0.1216 - val_root_mean_squared_error: 0.1689 - lr: 0.0010
# Epoch 25/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0409 - mae: 0.1409 - root_mean_squared_error: 0.2023
# Epoch 25: val_loss improved from 0.02852 to 0.02687, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_gru_model.h5
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0405 - mae: 0.1405 - root_mean_squared_error: 0.2011 - val_loss: 0.0269 - val_mae: 0.1176 - val_root_mean_squared_error: 0.1639 - lr: 0.0010
# Epoch 26/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0562 - mae: 0.1493 - root_mean_squared_error: 0.2371
# Epoch 26: val_loss did not improve from 0.02687
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0566 - mae: 0.1498 - root_mean_squared_error: 0.2380 - val_loss: 0.0334 - val_mae: 0.1265 - val_root_mean_squared_error: 0.1828 - lr: 0.0010
# Epoch 27/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0490 - mae: 0.1489 - root_mean_squared_error: 0.2214
# Epoch 27: val_loss did not improve from 0.02687
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0496 - mae: 0.1489 - root_mean_squared_error: 0.2227 - val_loss: 0.0405 - val_mae: 0.1397 - val_root_mean_squared_error: 0.2011 - lr: 0.0010
# Epoch 28/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0420 - mae: 0.1361 - root_mean_squared_error: 0.2049
# Epoch 28: val_loss did not improve from 0.02687
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0472 - mae: 0.1393 - root_mean_squared_error: 0.2172 - val_loss: 0.0643 - val_mae: 0.1686 - val_root_mean_squared_error: 0.2535 - lr: 0.0010
# Epoch 29/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0449 - mae: 0.1497 - root_mean_squared_error: 0.2118
# Epoch 29: val_loss did not improve from 0.02687
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0489 - mae: 0.1511 - root_mean_squared_error: 0.2212 - val_loss: 0.0375 - val_mae: 0.1391 - val_root_mean_squared_error: 0.1936 - lr: 0.0010
# Epoch 30/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0391 - mae: 0.1398 - root_mean_squared_error: 0.1976
# Epoch 30: val_loss did not improve from 0.02687
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0400 - mae: 0.1414 - root_mean_squared_error: 0.2001 - val_loss: 0.0312 - val_mae: 0.1268 - val_root_mean_squared_error: 0.1766 - lr: 0.0010
# Epoch 31/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0470 - mae: 0.1446 - root_mean_squared_error: 0.2169
# Epoch 31: val_loss did not improve from 0.02687
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0482 - mae: 0.1467 - root_mean_squared_error: 0.2195 - val_loss: 0.0348 - val_mae: 0.1307 - val_root_mean_squared_error: 0.1867 - lr: 0.0010
# Epoch 32/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0440 - mae: 0.1441 - root_mean_squared_error: 0.2097
# Epoch 32: val_loss improved from 0.02687 to 0.02637, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_gru_model.h5
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0451 - mae: 0.1445 - root_mean_squared_error: 0.2124 - val_loss: 0.0264 - val_mae: 0.1171 - val_root_mean_squared_error: 0.1624 - lr: 0.0010
# Epoch 33/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0355 - mae: 0.1298 - root_mean_squared_error: 0.1884
# Epoch 33: val_loss improved from 0.02637 to 0.02590, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_gru_model.h5
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0358 - mae: 0.1300 - root_mean_squared_error: 0.1893 - val_loss: 0.0259 - val_mae: 0.1167 - val_root_mean_squared_error: 0.1609 - lr: 0.0010
# Epoch 34/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0402 - mae: 0.1336 - root_mean_squared_error: 0.2004
# Epoch 34: val_loss improved from 0.02590 to 0.02573, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_gru_model.h5
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0396 - mae: 0.1324 - root_mean_squared_error: 0.1991 - val_loss: 0.0257 - val_mae: 0.1186 - val_root_mean_squared_error: 0.1604 - lr: 0.0010
# Epoch 35/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0451 - mae: 0.1412 - root_mean_squared_error: 0.2124
# Epoch 35: val_loss did not improve from 0.02573
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0448 - mae: 0.1416 - root_mean_squared_error: 0.2117 - val_loss: 0.0364 - val_mae: 0.1393 - val_root_mean_squared_error: 0.1908 - lr: 0.0010
# Epoch 36/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0441 - mae: 0.1330 - root_mean_squared_error: 0.2101
# Epoch 36: val_loss did not improve from 0.02573
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0494 - mae: 0.1345 - root_mean_squared_error: 0.2223 - val_loss: 0.0346 - val_mae: 0.1297 - val_root_mean_squared_error: 0.1861 - lr: 0.0010
# Epoch 37/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0438 - mae: 0.1417 - root_mean_squared_error: 0.2093
# Epoch 37: val_loss did not improve from 0.02573
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0457 - mae: 0.1432 - root_mean_squared_error: 0.2138 - val_loss: 0.0338 - val_mae: 0.1251 - val_root_mean_squared_error: 0.1839 - lr: 0.0010
# Epoch 38/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0479 - mae: 0.1439 - root_mean_squared_error: 0.2189
# Epoch 38: val_loss did not improve from 0.02573
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0465 - mae: 0.1426 - root_mean_squared_error: 0.2155 - val_loss: 0.0382 - val_mae: 0.1310 - val_root_mean_squared_error: 0.1953 - lr: 0.0010
# Epoch 39/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0367 - mae: 0.1280 - root_mean_squared_error: 0.1915
# Epoch 39: val_loss did not improve from 0.02573
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0369 - mae: 0.1283 - root_mean_squared_error: 0.1922 - val_loss: 0.0379 - val_mae: 0.1391 - val_root_mean_squared_error: 0.1946 - lr: 0.0010
# Epoch 40/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0412 - mae: 0.1350 - root_mean_squared_error: 0.2030
# Epoch 40: val_loss did not improve from 0.02573
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0408 - mae: 0.1356 - root_mean_squared_error: 0.2020 - val_loss: 0.0381 - val_mae: 0.1438 - val_root_mean_squared_error: 0.1953 - lr: 0.0010
# Epoch 41/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0463 - mae: 0.1474 - root_mean_squared_error: 0.2151
# Epoch 41: val_loss did not improve from 0.02573
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0460 - mae: 0.1478 - root_mean_squared_error: 0.2144 - val_loss: 0.0289 - val_mae: 0.1216 - val_root_mean_squared_error: 0.1700 - lr: 0.0010
# Epoch 42/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0479 - mae: 0.1485 - root_mean_squared_error: 0.2190
# Epoch 42: val_loss did not improve from 0.02573
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0467 - mae: 0.1474 - root_mean_squared_error: 0.2161 - val_loss: 0.0494 - val_mae: 0.1579 - val_root_mean_squared_error: 0.2222 - lr: 0.0010
# Epoch 43/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0419 - mae: 0.1330 - root_mean_squared_error: 0.2046
# Epoch 43: val_loss did not improve from 0.02573
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0485 - mae: 0.1359 - root_mean_squared_error: 0.2202 - val_loss: 0.0330 - val_mae: 0.1269 - val_root_mean_squared_error: 0.1817 - lr: 0.0010
# Epoch 44/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0456 - mae: 0.1440 - root_mean_squared_error: 0.2136
# Epoch 44: val_loss did not improve from 0.02573
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0492 - mae: 0.1469 - root_mean_squared_error: 0.2217 - val_loss: 0.0339 - val_mae: 0.1446 - val_root_mean_squared_error: 0.1842 - lr: 0.0010
# Epoch 45/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0500 - mae: 0.1434 - root_mean_squared_error: 0.2236
# Epoch 45: val_loss did not improve from 0.02573
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0487 - mae: 0.1424 - root_mean_squared_error: 0.2206 - val_loss: 0.0392 - val_mae: 0.1500 - val_root_mean_squared_error: 0.1981 - lr: 0.0010
# Epoch 46/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0503 - mae: 0.1434 - root_mean_squared_error: 0.2242
# Epoch 46: val_loss did not improve from 0.02573
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0488 - mae: 0.1427 - root_mean_squared_error: 0.2209 - val_loss: 0.0327 - val_mae: 0.1347 - val_root_mean_squared_error: 0.1807 - lr: 0.0010
# Epoch 47/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0406 - mae: 0.1412 - root_mean_squared_error: 0.2014
# Epoch 47: val_loss did not improve from 0.02573
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0413 - mae: 0.1402 - root_mean_squared_error: 0.2032 - val_loss: 0.0345 - val_mae: 0.1340 - val_root_mean_squared_error: 0.1858 - lr: 0.0010
# Epoch 48/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0488 - mae: 0.1460 - root_mean_squared_error: 0.2210
# Epoch 48: val_loss did not improve from 0.02573
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0486 - mae: 0.1466 - root_mean_squared_error: 0.2204 - val_loss: 0.0382 - val_mae: 0.1416 - val_root_mean_squared_error: 0.1955 - lr: 0.0010
# Epoch 49/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0405 - mae: 0.1348 - root_mean_squared_error: 0.2013
# Epoch 49: val_loss did not improve from 0.02573
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0488 - mae: 0.1369 - root_mean_squared_error: 0.2210 - val_loss: 0.0434 - val_mae: 0.1375 - val_root_mean_squared_error: 0.2083 - lr: 0.0010
# Epoch 50/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0589 - mae: 0.1463 - root_mean_squared_error: 0.2426
# Epoch 50: val_loss did not improve from 0.02573
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0618 - mae: 0.1466 - root_mean_squared_error: 0.2486 - val_loss: 0.0377 - val_mae: 0.1323 - val_root_mean_squared_error: 0.1942 - lr: 5.0000e-04
# Epoch 51/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0333 - mae: 0.1237 - root_mean_squared_error: 0.1825
# Epoch 51: val_loss improved from 0.02573 to 0.02346, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_gru_model.h5
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0361 - mae: 0.1253 - root_mean_squared_error: 0.1901 - val_loss: 0.0235 - val_mae: 0.1124 - val_root_mean_squared_error: 0.1532 - lr: 5.0000e-04
# Epoch 52/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0318 - mae: 0.1154 - root_mean_squared_error: 0.1783
# Epoch 52: val_loss did not improve from 0.02346
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0342 - mae: 0.1170 - root_mean_squared_error: 0.1850 - val_loss: 0.0273 - val_mae: 0.1211 - val_root_mean_squared_error: 0.1653 - lr: 5.0000e-04
# Epoch 53/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0401 - mae: 0.1264 - root_mean_squared_error: 0.2001
# Epoch 53: val_loss did not improve from 0.02346
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0398 - mae: 0.1262 - root_mean_squared_error: 0.1994 - val_loss: 0.0287 - val_mae: 0.1225 - val_root_mean_squared_error: 0.1695 - lr: 5.0000e-04
# Epoch 54/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0363 - mae: 0.1220 - root_mean_squared_error: 0.1906
# Epoch 54: val_loss did not improve from 0.02346
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0359 - mae: 0.1214 - root_mean_squared_error: 0.1896 - val_loss: 0.0251 - val_mae: 0.1128 - val_root_mean_squared_error: 0.1585 - lr: 5.0000e-04
# Epoch 55/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0321 - mae: 0.1182 - root_mean_squared_error: 0.1791
# Epoch 55: val_loss did not improve from 0.02346
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0325 - mae: 0.1188 - root_mean_squared_error: 0.1803 - val_loss: 0.0289 - val_mae: 0.1217 - val_root_mean_squared_error: 0.1701 - lr: 5.0000e-04
# Epoch 56/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0279 - mae: 0.1103 - root_mean_squared_error: 0.1670
# Epoch 56: val_loss did not improve from 0.02346
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0280 - mae: 0.1100 - root_mean_squared_error: 0.1672 - val_loss: 0.0261 - val_mae: 0.1138 - val_root_mean_squared_error: 0.1615 - lr: 5.0000e-04
# Epoch 57/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0344 - mae: 0.1143 - root_mean_squared_error: 0.1855
# Epoch 57: val_loss did not improve from 0.02346
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0345 - mae: 0.1157 - root_mean_squared_error: 0.1857 - val_loss: 0.0250 - val_mae: 0.1157 - val_root_mean_squared_error: 0.1582 - lr: 5.0000e-04
# Epoch 58/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0334 - mae: 0.1196 - root_mean_squared_error: 0.1828
# Epoch 58: val_loss did not improve from 0.02346
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0369 - mae: 0.1216 - root_mean_squared_error: 0.1920 - val_loss: 0.0239 - val_mae: 0.1127 - val_root_mean_squared_error: 0.1546 - lr: 5.0000e-04
# Epoch 59/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0319 - mae: 0.1136 - root_mean_squared_error: 0.1785
# Epoch 59: val_loss did not improve from 0.02346
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0313 - mae: 0.1126 - root_mean_squared_error: 0.1769 - val_loss: 0.0248 - val_mae: 0.1110 - val_root_mean_squared_error: 0.1574 - lr: 5.0000e-04
# Epoch 60/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0360 - mae: 0.1265 - root_mean_squared_error: 0.1896
# Epoch 60: val_loss did not improve from 0.02346
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0367 - mae: 0.1272 - root_mean_squared_error: 0.1915 - val_loss: 0.0324 - val_mae: 0.1328 - val_root_mean_squared_error: 0.1800 - lr: 5.0000e-04
# Epoch 61/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0391 - mae: 0.1320 - root_mean_squared_error: 0.1977
# Epoch 61: val_loss did not improve from 0.02346
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0376 - mae: 0.1294 - root_mean_squared_error: 0.1939 - val_loss: 0.0306 - val_mae: 0.1281 - val_root_mean_squared_error: 0.1750 - lr: 5.0000e-04
# Epoch 62/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0311 - mae: 0.1187 - root_mean_squared_error: 0.1763
# Epoch 62: val_loss improved from 0.02346 to 0.02318, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_gru_model.h5
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0340 - mae: 0.1203 - root_mean_squared_error: 0.1843 - val_loss: 0.0232 - val_mae: 0.1126 - val_root_mean_squared_error: 0.1523 - lr: 5.0000e-04
# Epoch 63/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0350 - mae: 0.1238 - root_mean_squared_error: 0.1870
# Epoch 63: val_loss did not improve from 0.02318
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0351 - mae: 0.1240 - root_mean_squared_error: 0.1872 - val_loss: 0.0268 - val_mae: 0.1210 - val_root_mean_squared_error: 0.1638 - lr: 5.0000e-04
# Epoch 64/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0258 - mae: 0.1100 - root_mean_squared_error: 0.1605
# Epoch 64: val_loss did not improve from 0.02318
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0280 - mae: 0.1114 - root_mean_squared_error: 0.1674 - val_loss: 0.0252 - val_mae: 0.1146 - val_root_mean_squared_error: 0.1589 - lr: 5.0000e-04
# Epoch 65/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0319 - mae: 0.1218 - root_mean_squared_error: 0.1786
# Epoch 65: val_loss improved from 0.02318 to 0.02298, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_gru_model.h5
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0317 - mae: 0.1211 - root_mean_squared_error: 0.1780 - val_loss: 0.0230 - val_mae: 0.1146 - val_root_mean_squared_error: 0.1516 - lr: 5.0000e-04
# Epoch 66/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0355 - mae: 0.1213 - root_mean_squared_error: 0.1884
# Epoch 66: val_loss improved from 0.02298 to 0.02286, saving model to d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\best_gru_model.h5
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0353 - mae: 0.1210 - root_mean_squared_error: 0.1880 - val_loss: 0.0229 - val_mae: 0.1106 - val_root_mean_squared_error: 0.1512 - lr: 5.0000e-04
# Epoch 67/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0415 - mae: 0.1232 - root_mean_squared_error: 0.2036
# Epoch 67: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0408 - mae: 0.1233 - root_mean_squared_error: 0.2021 - val_loss: 0.0247 - val_mae: 0.1162 - val_root_mean_squared_error: 0.1570 - lr: 5.0000e-04
# Epoch 68/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0358 - mae: 0.1195 - root_mean_squared_error: 0.1892
# Epoch 68: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0443 - mae: 0.1215 - root_mean_squared_error: 0.2106 - val_loss: 0.0280 - val_mae: 0.1215 - val_root_mean_squared_error: 0.1673 - lr: 5.0000e-04
# Epoch 69/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0361 - mae: 0.1268 - root_mean_squared_error: 0.1901
# Epoch 69: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0360 - mae: 0.1267 - root_mean_squared_error: 0.1898 - val_loss: 0.0306 - val_mae: 0.1288 - val_root_mean_squared_error: 0.1748 - lr: 5.0000e-04
# Epoch 70/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0368 - mae: 0.1191 - root_mean_squared_error: 0.1918
# Epoch 70: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0364 - mae: 0.1185 - root_mean_squared_error: 0.1908 - val_loss: 0.0250 - val_mae: 0.1133 - val_root_mean_squared_error: 0.1581 - lr: 5.0000e-04
# Epoch 71/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0359 - mae: 0.1194 - root_mean_squared_error: 0.1894
# Epoch 71: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0357 - mae: 0.1195 - root_mean_squared_error: 0.1890 - val_loss: 0.0256 - val_mae: 0.1199 - val_root_mean_squared_error: 0.1601 - lr: 5.0000e-04
# Epoch 72/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0363 - mae: 0.1266 - root_mean_squared_error: 0.1906
# Epoch 72: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0352 - mae: 0.1248 - root_mean_squared_error: 0.1877 - val_loss: 0.0280 - val_mae: 0.1247 - val_root_mean_squared_error: 0.1674 - lr: 5.0000e-04
# Epoch 73/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0350 - mae: 0.1218 - root_mean_squared_error: 0.1870
# Epoch 73: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0389 - mae: 0.1235 - root_mean_squared_error: 0.1972 - val_loss: 0.0248 - val_mae: 0.1135 - val_root_mean_squared_error: 0.1575 - lr: 5.0000e-04
# Epoch 74/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0351 - mae: 0.1272 - root_mean_squared_error: 0.1874
# Epoch 74: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0370 - mae: 0.1285 - root_mean_squared_error: 0.1923 - val_loss: 0.0257 - val_mae: 0.1166 - val_root_mean_squared_error: 0.1603 - lr: 5.0000e-04
# Epoch 75/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0362 - mae: 0.1158 - root_mean_squared_error: 0.1904
# Epoch 75: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0361 - mae: 0.1161 - root_mean_squared_error: 0.1900 - val_loss: 0.0269 - val_mae: 0.1200 - val_root_mean_squared_error: 0.1639 - lr: 5.0000e-04
# Epoch 76/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0264 - mae: 0.1112 - root_mean_squared_error: 0.1625
# Epoch 76: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0281 - mae: 0.1117 - root_mean_squared_error: 0.1676 - val_loss: 0.0279 - val_mae: 0.1146 - val_root_mean_squared_error: 0.1669 - lr: 5.0000e-04
# Epoch 77/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0353 - mae: 0.1234 - root_mean_squared_error: 0.1878
# Epoch 77: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0442 - mae: 0.1253 - root_mean_squared_error: 0.2102 - val_loss: 0.0362 - val_mae: 0.1355 - val_root_mean_squared_error: 0.1903 - lr: 5.0000e-04
# Epoch 78/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0326 - mae: 0.1222 - root_mean_squared_error: 0.1807
# Epoch 78: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0321 - mae: 0.1218 - root_mean_squared_error: 0.1792 - val_loss: 0.0239 - val_mae: 0.1144 - val_root_mean_squared_error: 0.1548 - lr: 5.0000e-04
# Epoch 79/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0346 - mae: 0.1199 - root_mean_squared_error: 0.1859
# Epoch 79: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0341 - mae: 0.1192 - root_mean_squared_error: 0.1847 - val_loss: 0.0271 - val_mae: 0.1137 - val_root_mean_squared_error: 0.1646 - lr: 5.0000e-04
# Epoch 80/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0431 - mae: 0.1329 - root_mean_squared_error: 0.2075
# Epoch 80: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0428 - mae: 0.1331 - root_mean_squared_error: 0.2069 - val_loss: 0.0293 - val_mae: 0.1277 - val_root_mean_squared_error: 0.1712 - lr: 5.0000e-04
# Epoch 81/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0308 - mae: 0.1200 - root_mean_squared_error: 0.1754
# Epoch 81: val_loss did not improve from 0.02286
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0310 - mae: 0.1211 - root_mean_squared_error: 0.1760 - val_loss: 0.0254 - val_mae: 0.1156 - val_root_mean_squared_error: 0.1593 - lr: 5.0000e-04
# Epoch 82/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0436 - mae: 0.1259 - root_mean_squared_error: 0.2089
# Epoch 82: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0426 - mae: 0.1256 - root_mean_squared_error: 0.2063 - val_loss: 0.0370 - val_mae: 0.1364 - val_root_mean_squared_error: 0.1924 - lr: 2.5000e-04
# Epoch 83/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0349 - mae: 0.1210 - root_mean_squared_error: 0.1867
# Epoch 83: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0333 - mae: 0.1185 - root_mean_squared_error: 0.1826 - val_loss: 0.0266 - val_mae: 0.1163 - val_root_mean_squared_error: 0.1631 - lr: 2.5000e-04
# Epoch 84/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0370 - mae: 0.1161 - root_mean_squared_error: 0.1925
# Epoch 84: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0457 - mae: 0.1185 - root_mean_squared_error: 0.2138 - val_loss: 0.0289 - val_mae: 0.1172 - val_root_mean_squared_error: 0.1699 - lr: 2.5000e-04
# Epoch 85/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0318 - mae: 0.1153 - root_mean_squared_error: 0.1784
# Epoch 85: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0358 - mae: 0.1183 - root_mean_squared_error: 0.1892 - val_loss: 0.0327 - val_mae: 0.1238 - val_root_mean_squared_error: 0.1809 - lr: 2.5000e-04
# Epoch 86/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0270 - mae: 0.1078 - root_mean_squared_error: 0.1643
# Epoch 86: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0285 - mae: 0.1091 - root_mean_squared_error: 0.1687 - val_loss: 0.0285 - val_mae: 0.1181 - val_root_mean_squared_error: 0.1687 - lr: 2.5000e-04
# Epoch 87/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0321 - mae: 0.1170 - root_mean_squared_error: 0.1791
# Epoch 87: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0333 - mae: 0.1181 - root_mean_squared_error: 0.1825 - val_loss: 0.0274 - val_mae: 0.1167 - val_root_mean_squared_error: 0.1654 - lr: 2.5000e-04
# Epoch 88/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0295 - mae: 0.1090 - root_mean_squared_error: 0.1717
# Epoch 88: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0315 - mae: 0.1096 - root_mean_squared_error: 0.1776 - val_loss: 0.0264 - val_mae: 0.1156 - val_root_mean_squared_error: 0.1624 - lr: 2.5000e-04
# Epoch 89/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0254 - mae: 0.1066 - root_mean_squared_error: 0.1595
# Epoch 89: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0263 - mae: 0.1077 - root_mean_squared_error: 0.1621 - val_loss: 0.0293 - val_mae: 0.1208 - val_root_mean_squared_error: 0.1713 - lr: 2.5000e-04
# Epoch 90/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0299 - mae: 0.1118 - root_mean_squared_error: 0.1730
# Epoch 90: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0326 - mae: 0.1125 - root_mean_squared_error: 0.1805 - val_loss: 0.0267 - val_mae: 0.1164 - val_root_mean_squared_error: 0.1633 - lr: 2.5000e-04
# Epoch 91/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0267 - mae: 0.1053 - root_mean_squared_error: 0.1634
# Epoch 91: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0287 - mae: 0.1070 - root_mean_squared_error: 0.1693 - val_loss: 0.0257 - val_mae: 0.1159 - val_root_mean_squared_error: 0.1604 - lr: 2.5000e-04
# Epoch 92/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0282 - mae: 0.1082 - root_mean_squared_error: 0.1678
# Epoch 92: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0280 - mae: 0.1091 - root_mean_squared_error: 0.1672 - val_loss: 0.0346 - val_mae: 0.1297 - val_root_mean_squared_error: 0.1861 - lr: 2.5000e-04
# Epoch 93/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0275 - mae: 0.1092 - root_mean_squared_error: 0.1658
# Epoch 93: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0291 - mae: 0.1114 - root_mean_squared_error: 0.1706 - val_loss: 0.0329 - val_mae: 0.1273 - val_root_mean_squared_error: 0.1815 - lr: 2.5000e-04
# Epoch 94/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0332 - mae: 0.1180 - root_mean_squared_error: 0.1821
# Epoch 94: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0329 - mae: 0.1177 - root_mean_squared_error: 0.1813 - val_loss: 0.0289 - val_mae: 0.1202 - val_root_mean_squared_error: 0.1700 - lr: 2.5000e-04
# Epoch 95/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0338 - mae: 0.1125 - root_mean_squared_error: 0.1839
# Epoch 95: val_loss did not improve from 0.02286
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0336 - mae: 0.1131 - root_mean_squared_error: 0.1834 - val_loss: 0.0285 - val_mae: 0.1202 - val_root_mean_squared_error: 0.1687 - lr: 2.5000e-04
# Epoch 96/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.0258 - mae: 0.1113 - root_mean_squared_error: 0.1607Restoring model weights from the end of the best epoch: 66.
#
# Epoch 96: val_loss did not improve from 0.02286
#
# Epoch 96: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0285 - mae: 0.1126 - root_mean_squared_error: 0.1689 - val_loss: 0.0311 - val_mae: 0.1256 - val_root_mean_squared_error: 0.1764 - lr: 2.5000e-04
# Epoch 96: early stopping
#
# ✓ GRU訓練完成！

# %% [markdown]
# ---
# ## 6. 三模型訓練過程比較

# %%
# 比較三個模型的訓練歷史
fig, axes = plt.subplots(2, 3, figsize=(20, 10))
fig.suptitle('Training History Comparison (SimpleRNN / LSTM / GRU)', fontsize=18, y=1.02)
plt.subplots_adjust(top=0.92)

histories = {
    'SimpleRNN': history_rnn,
    'LSTM': history_lstm,
    'GRU': history_gru
}

colors = {
    'SimpleRNN': 'skyblue',
    'LSTM': 'coral',
    'GRU': 'lightgreen'
}

# 第一行：訓練Loss
for idx, (name, hist) in enumerate(histories.items()):
    axes[0, idx].plot(hist.history['loss'], label='Train Loss', linewidth=2, color=colors[name], alpha=0.7)
    axes[0, idx].plot(hist.history['val_loss'], label='Val Loss', linewidth=2, color=colors[name], linestyle='--')
    axes[0, idx].set_xlabel('Epoch')
    axes[0, idx].set_ylabel('Loss (MSE)')
    axes[0, idx].set_title(f'{name} - Loss')
    axes[0, idx].legend()
    axes[0, idx].grid(True, alpha=0.3)
    
    # 標註最佳epoch
    best_epoch = np.argmin(hist.history['val_loss'])
    best_val_loss = np.min(hist.history['val_loss'])
    axes[0, idx].scatter([best_epoch], [best_val_loss], color='red', s=100, zorder=5)
    axes[0, idx].annotate(f'Best: {best_val_loss:.4f}\nEpoch {best_epoch}', 
                         xy=(best_epoch, best_val_loss),
                         xytext=(10, 10), textcoords='offset points',
                         bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.7),
                         fontsize=9)

# 第二行：MAE
for idx, (name, hist) in enumerate(histories.items()):
    axes[1, idx].plot(hist.history['mae'], label='Train MAE', linewidth=2, color=colors[name], alpha=0.7)
    axes[1, idx].plot(hist.history['val_mae'], label='Val MAE', linewidth=2, color=colors[name], linestyle='--')
    axes[1, idx].set_xlabel('Epoch')
    axes[1, idx].set_ylabel('MAE')
    axes[1, idx].set_title(f'{name} - MAE')
    axes[1, idx].legend()
    axes[1, idx].grid(True, alpha=0.3)
    
    # 標註最佳epoch
    best_epoch = np.argmin(hist.history['val_mae'])
    best_val_mae = np.min(hist.history['val_mae'])
    axes[1, idx].scatter([best_epoch], [best_val_mae], color='red', s=100, zorder=5)

plt.tight_layout()
plt.savefig(FIG_DIR / 'all_models_training_history.png', dpi=150, bbox_inches='tight')
plt.show()

print("✓ 三模型訓練歷史對比圖已保存")
# Out:
# ✓ 三模型訓練歷史對比圖已保存

# %% [markdown]
# ---
# ## 7. 三模型性能評估

# %%
# 評估所有三個模型
print("=== 三模型性能評估 ===\n")

models_dict = {
    'SimpleRNN': model_rnn,
    'LSTM': model_lstm,
    'GRU': model_gru
}

results_comparison = {}

for name, model_eval in models_dict.items():
    print(f"\n{'='*50}")
    print(f"評估 {name} 模型")
    print(f"{'='*50}")
    
    # 在測試集上評估
    test_results = model_eval.evaluate(X_test_scaled, y_test_scaled, verbose=0)
    
    print(f"\n測試集性能 (標準化數據):")
    print(f"  Loss (MSE): {test_results[0]:.4f}")
    print(f"  MAE: {test_results[1]:.4f}")
    print(f"  RMSE: {test_results[2]:.4f}")
    
    # 預測並反標準化
    y_pred_scaled = model_eval.predict(X_test_scaled, verbose=0)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)
    
    # 計算原始尺度上的指標
    mae_original = mean_absolute_error(y_test, y_pred)
    mse_original = mean_squared_error(y_test, y_pred)
    rmse_original = np.sqrt(mse_original)
    r2 = r2_score(y_test, y_pred)
    
    print(f"\n測試集性能 (原始尺度):")
    print(f"  MAE: {mae_original:.4f}")
    print(f"  MSE: {mse_original:.4f}")
    print(f"  RMSE: {rmse_original:.4f}")
    print(f"  R²: {r2:.4f}")
    
    # 保存結果
    results_comparison[name] = {
        'mae': mae_original,
        'mse': mse_original,
        'rmse': rmse_original,
        'r2': r2,
        'predictions': y_pred
    }

print(f"\n{'='*50}")
print("✓ 所有模型評估完成")
print(f"{'='*50}")
# Out:
# === 三模型性能評估 ===
#
#
# ==================================================
# 評估 SimpleRNN 模型
# ==================================================
#
# 測試集性能 (標準化數據):
#   Loss (MSE): 0.0783
#   MAE: 0.1745
#   RMSE: 0.2798
#
# 測試集性能 (原始尺度):
#   MAE: 0.5765
#   MSE: 0.8541
#   RMSE: 0.9242
#   R²: 0.9400
#
# ==================================================
# 評估 LSTM 模型
# ==================================================
#
# 測試集性能 (標準化數據):
#   Loss (MSE): 0.0344
#   MAE: 0.1102
#   RMSE: 0.1856
#
# 測試集性能 (原始尺度):
#   MAE: 0.3639
#   MSE: 0.3757
#   RMSE: 0.6129
#   R²: 0.9736
#
# ==================================================
# 評估 GRU 模型
# ==================================================
#
# 測試集性能 (標準化數據):
#   Loss (MSE): 0.0448
#   MAE: 0.1235
#   RMSE: 0.2117
#
# 測試集性能 (原始尺度):
#   MAE: 0.4078
#   MSE: 0.4892
#   RMSE: 0.6994
#   R²: 0.9656
#
# ==================================================
# ✓ 所有模型評估完成
# ==================================================

# %% [markdown]
# ---
# ## 8. 三模型性能比較視覺化

# %%
# Create comprehensive comparison figure
fig = plt.figure(figsize=(20, 12))
gs = fig.add_gridspec(3, 4, hspace=0.3, wspace=0.3)

# ===== First row: metric bar plots =====
metrics = ['MAE', 'RMSE', 'R²']
ax1 = fig.add_subplot(gs[0, :2])
ax2 = fig.add_subplot(gs[0, 2])
ax3 = fig.add_subplot(gs[0, 3])

# MAE comparison
mae_values = [results_comparison[name]['mae'] for name in models_dict.keys()]
bars1 = ax1.bar(models_dict.keys(), mae_values, color=[colors[name] for name in models_dict.keys()])
ax1.set_ylabel('MAE')
ax1.set_title('Mean Absolute Error Comparison', fontweight='bold')
ax1.grid(axis='y', alpha=0.3)
for i, (bar, val) in enumerate(zip(bars1, mae_values)):
    ax1.text(bar.get_x() + bar.get_width()/2, bar.get_height(), 
             f'{val:.4f}', ha='center', va='bottom', fontweight='bold')

# RMSE comparison
rmse_values = [results_comparison[name]['rmse'] for name in models_dict.keys()]
bars2 = ax2.bar(models_dict.keys(), rmse_values, color=[colors[name] for name in models_dict.keys()])
ax2.set_ylabel('RMSE')
ax2.set_title('RMSE Comparison', fontweight='bold')
ax2.grid(axis='y', alpha=0.3)
for bar, val in zip(bars2, rmse_values):
    ax2.text(bar.get_x() + bar.get_width()/2, bar.get_height(), 
             f'{val:.4f}', ha='center', va='bottom', fontweight='bold')

# R² comparison
r2_values = [results_comparison[name]['r2'] for name in models_dict.keys()]
bars3 = ax3.bar(models_dict.keys(), r2_values, color=[colors[name] for name in models_dict.keys()])
ax3.set_ylabel('R²')
ax3.set_title('R² Score Comparison', fontweight='bold')
ax3.grid(axis='y', alpha=0.3)
ax3.set_ylim([min(r2_values) * 0.95, 1.0])
for bar, val in zip(bars3, r2_values):
    ax3.text(bar.get_x() + bar.get_width()/2, bar.get_height(), 
             f'{val:.4f}', ha='center', va='bottom', fontweight='bold')

# ===== Second row: Predictions vs Actual (first 100 samples) =====
n_show = 100
for idx, (name, results) in enumerate(results_comparison.items()):
    ax = fig.add_subplot(gs[1, idx])
    ax.plot(y_test[:n_show], label='Actual', linewidth=2, alpha=0.7, color='black')
    ax.plot(results['predictions'][:n_show], label='Predicted', 
            linewidth=2, alpha=0.7, color=colors[name], linestyle='--')
    ax.set_xlabel('Sample Index')
    ax.set_ylabel('Target Value')
    ax.set_title(f'{name}\nPredictions vs Actual', fontweight='bold')
    ax.legend(loc='best')
    ax.grid(True, alpha=0.3)

# ===== Third row: scatter plots and residual distribution =====
for idx, (name, results) in enumerate(results_comparison.items()):
    # Scatter plot
    ax = fig.add_subplot(gs[2, idx])
    ax.scatter(y_test, results['predictions'], alpha=0.5, s=20, color=colors[name])
    ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 
            'r--', lw=2, label='Perfect Prediction')
    ax.set_xlabel('Actual')
    ax.set_ylabel('Predicted')
    ax.set_title(f'{name}\nScatter Plot', fontweight='bold')
    ax.legend()
    ax.grid(True, alpha=0.3)

# Residual distribution (rightmost column)
ax_residual = fig.add_subplot(gs[2, 3])
for name, results in results_comparison.items():
    residuals = y_test.flatten() - results['predictions'].flatten()
    ax_residual.hist(residuals, bins=30, alpha=0.5, label=name, color=colors[name])
ax_residual.axvline(x=0, color='r', linestyle='--', linewidth=2)
ax_residual.set_xlabel('Residual')
ax_residual.set_ylabel('Frequency')
ax_residual.set_title('Residuals Distribution Comparison', fontweight='bold')
ax_residual.legend()
ax_residual.grid(True, alpha=0.3)

plt.suptitle('RNN Models Comprehensive Comparison', fontsize=20, fontweight='bold', y=0.995)
plt.savefig(FIG_DIR / 'all_models_comprehensive_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

print("✓ 綜合比較圖已保存")
# Out:
# ✓ 綜合比較圖已保存

# %% [markdown]
# ## 9 訓練時間與收斂速度比較

# %%
# 分析訓練收斂速度
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# 子圖1：收斂到最佳性能所需的epoch數
epochs_to_best = {}
for name, hist in histories.items():
    best_epoch = np.argmin(hist.history['val_loss'])
    epochs_to_best[name] = best_epoch + 1  # +1因為epoch從0開始

bars = axes[0].bar(epochs_to_best.keys(), epochs_to_best.values(), 
                   color=[colors[name] for name in epochs_to_best.keys()])
axes[0].set_ylabel('Epochs')
axes[0].set_title('Convergence speed (epoch to best val_loss)', fontweight='bold')
axes[0].grid(axis='y', alpha=0.3)
for bar, val in zip(bars, epochs_to_best.values()):
    axes[0].text(bar.get_x() + bar.get_width()/2, bar.get_height(), 
                str(val), ha='center', va='bottom', fontweight='bold', fontsize=12)

# 子圖2：最終訓練epochs數（實際訓練的總epoch數）
total_epochs = {name: len(hist.history['loss']) for name, hist in histories.items()}
bars = axes[1].bar(total_epochs.keys(), total_epochs.values(), 
                   color=[colors[name] for name in total_epochs.keys()])
axes[1].set_ylabel('Epochs')
axes[1].set_title('Total training epochs (including EarlyStopping)', fontweight='bold')
axes[1].grid(axis='y', alpha=0.3)
for bar, val in zip(bars, total_epochs.values()):
    axes[1].text(bar.get_x() + bar.get_width()/2, bar.get_height(), 
                str(val), ha='center', va='bottom', fontweight='bold', fontsize=12)

plt.tight_layout()
plt.savefig(FIG_DIR / 'convergence_speed_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

print("\n📈 收斂速度分析:")
for name in histories.keys():
    print(f"  {name:12s}: 最佳epoch={epochs_to_best[name]:3d}, 總訓練epoch={total_epochs[name]:3d}")

print("\n✓ 收斂速度比較圖已保存")
# Out:
# 📈 收斂速度分析:
#   SimpleRNN   : 最佳epoch= 30, 總訓練epoch= 60
#   LSTM        : 最佳epoch=176, 總訓練epoch=200
#   GRU         : 最佳epoch= 66, 總訓練epoch= 96
#
# ✓ 收斂速度比較圖已保存

# %% [markdown]
# ## 9 建立性能比較表格

# %%
# 建立詳細的性能比較表格
comparison_df = pd.DataFrame({
    'Model': list(results_comparison.keys()),
    'MAE': [results_comparison[name]['mae'] for name in results_comparison.keys()],
    'MSE': [results_comparison[name]['mse'] for name in results_comparison.keys()],
    'RMSE': [results_comparison[name]['rmse'] for name in results_comparison.keys()],
    'R²': [results_comparison[name]['r2'] for name in results_comparison.keys()],
    'Parameters': [model.count_params() for model in models_dict.values()]
})

# 計算相對於SimpleRNN的改進百分比
comparison_df['MAE_Improvement(%)'] = (
    (comparison_df['MAE'][0] - comparison_df['MAE']) / comparison_df['MAE'][0] * 100
)
comparison_df['RMSE_Improvement(%)'] = (
    (comparison_df['RMSE'][0] - comparison_df['RMSE']) / comparison_df['RMSE'][0] * 100
)

print("\n" + "="*100)
print("三模型性能比較表")
print("="*100)
print(comparison_df.to_string(index=False))
print("="*100)

# 找出最佳模型
best_mae_model = comparison_df.loc[comparison_df['MAE'].idxmin(), 'Model']
best_r2_model = comparison_df.loc[comparison_df['R²'].idxmax(), 'Model']
most_efficient = comparison_df.loc[comparison_df['Parameters'].idxmin(), 'Model']

print(f"\n📊 關鍵發現:")
print(f"  ✓ 最佳MAE性能: {best_mae_model} (MAE={comparison_df.loc[comparison_df['MAE'].idxmin(), 'MAE']:.4f})")
print(f"  ✓ 最佳R²性能: {best_r2_model} (R²={comparison_df.loc[comparison_df['R²'].idxmax(), 'R²']:.4f})")
print(f"  ✓ 最輕量模型: {most_efficient} ({comparison_df.loc[comparison_df['Parameters'].idxmin(), 'Parameters']:,} parameters)")

# 保存到CSV
comparison_csv_path = OUTPUT_DIR / 'models_comparison.csv'
comparison_df.to_csv(comparison_csv_path, index=False, encoding='utf-8-sig')
print(f"\n✓ 比較表已保存至: {comparison_csv_path}")
# Out:
# ====================================================================================================
# 三模型性能比較表
# ====================================================================================================
#     Model      MAE      MSE     RMSE       R²  Parameters  MAE_Improvement(%)  RMSE_Improvement(%)
# SimpleRNN 0.576547 0.854058 0.924152 0.939959        8449            0.000000             0.000000
#      LSTM 0.363914 0.375697 0.612942 0.973588      122689           36.880482            33.675279
#       GRU 0.407803 0.489215 0.699439 0.965608       93121           29.267968            24.315611
# ====================================================================================================
#
# 📊 關鍵發現:
#   ✓ 最佳MAE性能: LSTM (MAE=0.3639)
#   ✓ 最佳R²性能: LSTM (R²=0.9736)
#   ✓ 最輕量模型: SimpleRNN (8,449 parameters)
#
# ✓ 比較表已保存至: d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models_comparison.csv

# %% [markdown]
# ---
# ## 10. 模型保存與載入

# %% [markdown]
# ### 10.1 保存模型

# %%
# 保存所有三個模型
print("保存所有模型...\n")

for name, model_save in models_dict.items():
    # 保存完整模型
    model_path = MODEL_DIR / f'final_{name.lower()}_model.h5'
    model_save.save(model_path)
    print(f"✓ {name} 完整模型已保存至: {model_path}")
    
    # 保存權重
    weights_path = MODEL_DIR / f'{name.lower()}_weights.h5'
    model_save.save_weights(weights_path)
    print(f"✓ {name} 權重已保存至: {weights_path}")

# 保存scaler
scaler_path = MODEL_DIR / 'scalers.pkl'
joblib.dump({'scaler_X': scaler_X, 'scaler_y': scaler_y}, scaler_path)
print(f"\n✓ Scalers已保存至: {scaler_path}")

# 保存訓練歷史
history_path = MODEL_DIR / 'training_histories.pkl'
histories_to_save = {
    'SimpleRNN': history_rnn.history,
    'LSTM': history_lstm.history,
    'GRU': history_gru.history
}
joblib.dump(histories_to_save, history_path)
print(f"✓ 訓練歷史已保存至: {history_path}")

# 保存比較結果
comparison_path = MODEL_DIR / 'models_comparison.pkl'
joblib.dump(results_comparison, comparison_path)
print(f"✓ 比較結果已保存至: {comparison_path}")

print("\n" + "="*60)
print("✓ 所有模型和結果保存完成！")
print("="*60)
# Out:
# 保存所有模型...
#
# ✓ SimpleRNN 完整模型已保存至: d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\final_simplernn_model.h5
# ✓ SimpleRNN 權重已保存至: d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\simplernn_weights.h5
# ✓ LSTM 完整模型已保存至: d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\final_lstm_model.h5
# ✓ LSTM 權重已保存至: d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\lstm_weights.h5
# ✓ GRU 完整模型已保存至: d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\final_gru_model.h5
# ✓ GRU 權重已保存至: d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\gru_weights.h5
#
# ✓ Scalers已保存至: d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\scalers.pkl
# ✓ 訓練歷史已保存至: d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\training_histories.pkl
# ✓ 比較結果已保存至: d:\MyGit\CHE-AI-COURSE\Part_4\outputs\P4_Unit17_Results\models\models_comparison.pkl
#
# ============================================================
# ✓ 所有模型和結果保存完成！
# ============================================================

# %% [markdown]
# ### 10.2 載入模型

# %%
# 示範：載入最佳模型（以LSTM為例）
best_model_name = comparison_df.loc[comparison_df['MAE'].idxmin(), 'Model']
print(f"載入最佳模型: {best_model_name}\n")

model_path = MODEL_DIR / f'final_{best_model_name.lower()}_model.h5'
loaded_model = load_model(model_path)
print(f"✓ {best_model_name} 模型載入成功")

# 載入scalers
scalers = joblib.load(scaler_path)
loaded_scaler_X = scalers['scaler_X']
loaded_scaler_y = scalers['scaler_y']
print("✓ Scalers載入成功")

# 載入訓練歷史
loaded_histories = joblib.load(history_path)
print("✓ 訓練歷史載入成功")

# 驗證載入的模型
original_model = models_dict[best_model_name]
test_pred_loaded = loaded_model.predict(X_test_scaled[:5], verbose=0)
test_pred_original = original_model.predict(X_test_scaled[:5], verbose=0)

print(f"\n驗證載入的 {best_model_name} 模型:")
print(f"  預測差異: {np.abs(test_pred_loaded - test_pred_original).max():.10f}")
print("  ✓ 模型載入正確！" if np.allclose(test_pred_loaded, test_pred_original) else "  ✗ 模型載入有誤！")

# 顯示可用的已保存檔案
print(f"\n📁 已保存的檔案清單:")
for file in sorted(MODEL_DIR.glob('*')):
    file_size = file.stat().st_size / (1024 * 1024)  # MB
    print(f"  - {file.name:40s} ({file_size:.2f} MB)")
# Out:
# 載入最佳模型: LSTM
#
# ✓ LSTM 模型載入成功
# ✓ Scalers載入成功
# ✓ 訓練歷史載入成功
#
# 驗證載入的 LSTM 模型:
#   預測差異: 0.0000000000
#   ✓ 模型載入正確！
#
# 📁 已保存的檔案清單:
#   - best_gru_model.h5                        (1.11 MB)
#   - best_lstm_model.h5                       (1.45 MB)
#   - best_simple_rnn_model.h5                 (0.15 MB)
#   - final_gru_model.h5                       (1.11 MB)
#   - final_lstm_model.h5                      (1.45 MB)
#   - final_simplernn_model.h5                 (0.15 MB)
#   - gru_weights.h5                           (0.38 MB)
#   - lstm_weights.h5                          (0.49 MB)
#   - models_comparison.pkl                    (0.00 MB)
#   - scalers.pkl                              (0.00 MB)
#   - simplernn_weights.h5                     (0.05 MB)
#   - training_histories.pkl                   (0.02 MB)

# %% [markdown]
# ---
# ## 總結
#
# 本notebook完成了以下內容:
#
# ### ✅ 完成項目
#
# 1. **環境設定**: 配置Colab/Local環境，檢查GPU狀態
# 2. **數據準備**: 生成模擬時間序列數據 (2000樣本, 30時間步, 10特徵)
# 3. **數據處理**: 正確的分割順序與標準化流程
# 4. **模型建立**: 建立三種RNN架構
#    - SimpleRNN (基礎架構)
#    - LSTM (長短期記憶網路)
#    - GRU (門控循環單元)
# 5. **模型訓練**: 完整訓練所有三個模型
#    - 使用Adam優化器 + 梯度裁剪
#    - 設定EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#    - 正確設定 shuffle=False (時間序列專用)
# 6. **綜合比較**: 多維度比較三個模型
#    - 訓練過程視覺化 (Loss, MAE曲線)
#    - 性能指標對比 (MAE, RMSE, R²)
#    - 預測結果比較 (時序圖、散點圖、殘差)
#    - 收斂速度分析
#    - 參數量與效率權衡
# 7. **模型保存**: 保存所有模型、權重、scalers、訓練歷史
#
# ### 📊 實驗結果分析
#
# #### 1. 模型參數量對比
# ```
# - SimpleRNN:   8,449 parameters (基準)
# - LSTM:      122,689 parameters (14.5倍)
# - GRU:        93,121 parameters (11.0倍)
# ```
# **觀察**: LSTM參數量最多，GRU比LSTM少約24%，SimpleRNN最輕量
#
# #### 2. 測試集性能表現
# ```
# 模型性能指標 (原始尺度):
# ┌───────────┬─────────┬─────────┬──────┐
# │   Model   │   MAE   │  RMSE   │  R²  │
# ├───────────┼─────────┼─────────┼──────┤
# │ SimpleRNN │ 0.5765  │ 0.9242  │ 0.94 │
# │ LSTM      │ 0.3639  │ 0.6129  │ 0.97 │
# │ GRU       │ 0.4078  │ 0.6994  │ 0.97 │
# └───────────┴─────────┴─────────┴──────┘
# ```
#
# **關鍵發現**:
# - **LSTM表現最佳**: MAE=0.3639, R²=0.9736
#   - 相較SimpleRNN，MAE改善36.9%，RMSE改善33.7%
#   - 展現出色的長期依賴捕捉能力
#
# - **GRU位居第二**: MAE=0.4078, R²=0.9656
#   - 相較SimpleRNN，MAE改善29.3%，RMSE改善24.3%
#   - 參數量比LSTM少24%，性能僅略遜5-14%
#   - **最佳效率/性能比**
#
# - **SimpleRNN表現最差**: MAE=0.5765, R²=0.9400
#   - 雖然參數量最少，但在複雜時序模式上能力受限
#   - 適合簡單、短期依賴的時間序列
#
# #### 3. 收斂速度分析
# ```
# 收斂到最佳性能所需epoch:
# - SimpleRNN:  30 epoch (最快收斂)
# - GRU:        66 epoch (中等速度)
# - LSTM:      176 epoch (最慢收斂)
#
# 總訓練時間 (含EarlyStopping):
# - SimpleRNN:  60 epoch (提前停止)
# - GRU:        96 epoch (提前停止)
# - LSTM:      200 epoch (訓練完整個200 epoch)
# ```
#
# **觀察**:
# 1. **SimpleRNN收斂最快但易過擬合**:
#    - 30 epoch即達最佳，但在60 epoch時觸發EarlyStopping
#    - 可能欠擬合複雜模式，導致性能較差
#
# 2. **GRU平衡性最佳**:
#    - 66 epoch達到最佳性能
#    - 訓練穩定，在96 epoch提前停止
#    - 收斂速度是LSTM的2.7倍，性能僅略差
#
# 3. **LSTM訓練最慢但最穩定**:
#    - 需要176 epoch才達最佳性能
#    - 訓練完整200 epoch未提前停止
#    - 雖然慢但最終性能最佳
#
# ### 🎯 關鍵技術要點
#
# 1. **時間序列特殊處理**:
#    - 數據分割時必須 `shuffle=False`
#    - 訓練時必須 `shuffle=False`
#    - 先分割再標準化，避免數據洩漏
#
# 2. **梯度問題處理**:
#    - 使用 `clipnorm=1.0` 防止梯度爆炸
#    - LSTM/GRU的門控機制緩解梯度消失
#    - SimpleRNN容易遭受梯度消失問題
#
# 3. **模型選擇建議**:
#    | 場景 | 推薦模型 | 理由 |
#    |------|----------|------|
#    | **資源受限、快速原型** | SimpleRNN | 參數少(8K)、訓練快(60 epoch) |
#    | **追求最佳性能** | LSTM | R²=0.974、MAE最低、處理長期依賴最佳 |
#    | **實務生產環境** | GRU | 性能接近LSTM(僅差5%)、參數少24%、訓練快2.7倍 |
#    | **短期序列(<10步)** | SimpleRNN | 足夠應付短期依賴、效率最高 |
#    | **長期序列(>50步)** | LSTM | 門控機制有效保存長期記憶 |
#
# 4. **Callbacks組合策略**:
#    - EarlyStopping (patience=30): 防止過擬合，本實驗中SimpleRNN和GRU有效提前停止
#    - ModelCheckpoint: 確保保存最佳epoch的模型（如LSTM的第176 epoch）
#    - ReduceLROnPlateau (patience=15, factor=0.5): 動態降低學習率，幫助精細調整
#
# ### 💡 實務應用建議
#
# #### 化工製程場景選擇指南
#
# 1. **批次反應器品質預測** (30-60分鐘時序):
#    - **推薦**: GRU
#    - **原因**: 中等長度序列，需平衡預測準確度與計算效率
#    - **預期性能**: R² > 0.96
#
# 2. **連續製程異常檢測** (即時監控):
#    - **推薦**: SimpleRNN or GRU
#    - **原因**: 需要快速推論，短期依賴即可捕捉異常模式
#    - **預期性能**: 偵測延遲 < 5秒
#
# 3. **長期設備健康監測** (數週至數月):
#    - **推薦**: LSTM
#    - **原因**: 長期趨勢捕捉、RUL預測需要記憶遙遠過去的狀態
#    - **預期性能**: R² > 0.97，可提前數週預警
#
# 4. **能耗預測與優化** (日/週尺度):
#    - **推薦**: GRU
#    - **原因**: 週期性模式+中期依賴，GRU效率高適合頻繁重訓練
#    - **預期性能**: MAPE < 5%
#
# ### 📚 延伸學習方向
#
# 基於本次實驗結果，以下進階方向值得探索:
#
# - [ ] **雙向RNN (Bidirectional)**: 對完整時間序列分析，可能進一步提升5-10%性能
# - [ ] **堆疊更多層**: 目前僅2層，增加至3-4層可能捕捉更複雜模式（代價是訓練時間增加）
# - [ ] **Attention機制**: 加入attention可識別關鍵時間步，提升可解釋性
# - [ ] **多步預測 (Seq2Seq)**: 本實驗僅預測單一值，可擴展為預測未來多個時間步
# - [ ] **集成學習**: 結合LSTM+GRU可能獲得更穩健的預測
# - [ ] **超參數調優**: 調整層數、神經元數、學習率、Dropout等
# - [ ] **真實數據驗證**: 在真實化工數據集上驗證本實驗的結論
#
# ### 🔍 意外發現與討論
#
# 1. **LSTM未提前停止的原因**:
#    - 在第176 epoch達到最佳val_loss後，驗證集loss仍在緩慢下降
#    - patience=30內loss持續有輕微改善，因此訓練至200 epoch上限
#    - 顯示LSTM學習曲線更平緩，需要更多訓練時間
#
# 2. **GRU的高效率驚喜**:
#    - 預期GRU性能會明顯遜於LSTM，但實際僅差約5-14%
#    - 參數量少24%、訓練快2.7倍，是實務應用的最佳選擇
#    - 驗證了GRU在許多場景下可替代LSTM的論點
#
# 3. **SimpleRNN快速收斂的陷阱**:
#    - 雖然30 epoch即收斂，但實際是欠擬合而非高效學習
#    - 無法捕捉複雜的非線性時序依賴
#    - 僅適合極簡單或線性相關的時間序列
#
# ### ✨ 最終結論
#
# 本實驗全面比較了三種RNN架構在時間序列回歸任務上的表現。**LSTM在性能上最優異(R²=0.974)**，但**GRU在實務應用上更具優勢**，提供了接近的性能(R²=0.966)、更少的參數(93K vs 123K)、以及更快的訓練速度(66 vs 176 epoch)。對於大多數化工製程應用，**建議優先考慮GRU模型**，除非應用場景明確需要捕捉極長期的依賴關係。
